# %% [markdown]
# * <a href="https://colab.research.google.com/github/4dsolutions/clarusway_data_analysis/blob/main/Kirby%20Notebooks/Curated_Videos.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a><br/>
# * <a href="https://nbviewer.org/github/4dsolutions/clarusway_data_analysis/blob/main/Kirby%20Notebooks/Curated_Videos.ipynb"><img align="left" src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg" alt="Open in nbviewer" title="Open and View using nbviewer"></a>
#
#
# Landing Pages:
# * [Data Visualization](../DVwPY_S1/daily_schedule.ipynb)
# * [Data Analysis with Python](../DAwPy_S1_%28Numpy_Arrays%29/daily_schedule.ipynb)
# * [Basic Python](../basic_python/landing_page.ipynb)

# %% [markdown]
# # Data Science Videos

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# *Python Simplified* is a good one for distilling big concepts to clear explanations and understandable code examples.

# %%
YouTubeVideo("EJRFP3WmS6Q")

# %% [markdown]
# The talk below is one of the best I've come across when it comes to differentiating between the stages of model creation behind today's LLMs.

# %%
YouTubeVideo("zjkBMFhNj_g")

# %% [markdown]
# Remarks: the instructor speaks quickly, using a lot of shoptalk, however what goes by resonates with what we cover: dealing with nulls and outliers, data clearning, normalizing (rescaling), getting dummies, one hot encoding.

# %%
YouTubeVideo("zduSFxRajkE")

# %% [markdown]
# Diving into how tokenization works helps lay the foundation for vectorization.

# %%
YouTubeVideo("379s4W_EaTk")

# %% [markdown]
# In curating a video, I'm implicitly suggesting the entire channel be mined for gems. Thu Vu is a strong contributor when it comes to teaching about the disciplines of data science and AI.

# %%
YouTubeVideo("ip2HYPC_T9Q")

# %% [markdown]
# Tokenization applies to graphical as well as lexical info.

# %%
YouTubeVideo("oMc9StPVzOU") # Pitfalls in ML

# %% [markdown]
# Help your fellow data scientists by curating some favorite videos, or entire YouTube channels. Providing your own informed reviews helps you define yourself as an informed commentator in the professional content of your field.

# %%
YouTubeVideo("tFWsuO9f74o") # Confidance Intervals

# %% [markdown]
# In the old days, statistics involved published tables in books and looking up pre-calculated values, such a logs. Confidance intervals could be ascertained based on sample size n, standard deviation, and size of confidence interval required.
#
# A CI of 95% means: there's only a 5% chance (1 in 20) that the upper-lower range provided by sampling does not include the true value for the whole population. More variance in the sample requires wider CIs.  The bigger the sample, the narrower the CI.

# %%
YouTubeVideo("s4SRdaTycaw") # Tukey

# %% [markdown]
# Since computers have become ubiquitous, methods involving lookup tables have been replaced with actual computations. Bootstrapping would be a tedious and time-consuming way to go about finding a confidance interval if carried out manually. The YouTube below clearly describes the technique.

# %%
YouTubeVideo("655X9eZGxls") # Bootstrapping

# %% [markdown]
# If you don't find the AI voice too annoying (this voice is everywhere), you are likely to get value from this pithy condensed review of the different Machine Learning models.

# %%
YouTubeVideo("0YdpwSYMY6I")

# %% [markdown]
# Less about data science than core Python, the language.  Generators, Decorators, Complex Number Mathematics...

# %%
YouTubeVideo("9sMawhe6glU")
