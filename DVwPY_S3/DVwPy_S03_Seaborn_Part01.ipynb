# %% [markdown]
# <a href="https://clarusway.com/contact-us/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="Open in Clarusway LMS" width="110" height="200" title="This notebook is licensed by Clarusway IT training school. Please contact the authorized persons about the conditions under which you can use or share."></a>

# %% [markdown]
# <hr>
#
# <p style="text-align: center;"><a href="https://lms.clarusway.com/mod/lesson/view.php?id=2463&pageid=4531&startlastseen=no"><img align="center" src="https://i.ibb.co/6Z5pQxD/lmss.png" alt="Open in Clarusway LMS" width="70" height="200" title="Open Clarusway Learning Management Sytem"></a>
#
# <a href="https://github.com/4dsolutions/clarusway_data_analysis/blob/main/DVwPY_S3/DVwPy_S03_Seaborn_Part01.ipynb"><img align="left" src="https://i.ibb.co/n3HWyQX/github-logo.png" alt="Open in GitHub" width="90" height="150" title="Open and Execute in Clarusway GitHub Repository"></a>
#
# <a href="https://nbviewer.org/github/4dsolutions/clarusway_data_analysis/blob/main/DVwPY_S3/DVwPy_S03_Seaborn_Part01.ipynb"><img align="right" src="https://i.ibb.co/48wtV8c/nbviewer-badge.png" alt="Open in nbviewer" width="100" height="100" title="Open and Execute in nbviewer"></a><br/>
#
# <hr>
#
#
# <p style="text-align: center;"><img src="https://i.ibb.co/Rpz9L36/clarusway-logo-black.png" width="500" height="200" class="img-fluid" alt="CLRSWY_LOGO"></p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/XS0bxSH/best-bootcamps.png" width="300" height="200" class="img-fluid" alt="CLRSWY BEST BOOTCAMP"></p>
#
# <p style="background-color:#E51A59; font-family:newtimeroman; color:#FDFEFE; font-size:130%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/99DQ3TY/DS-Courses.png" class="img-fluid" alt="CLRSWY_Courses"></p>

# %% [markdown]
# <hr>
#
# ![seaborn.png](https://i.ibb.co/hg2Kd1X/seabornlogo.png)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#E51A59; font-size:150%; text-align:center; border-radius:10px 10px;">Session - 03 (Seaborn - Part-01)</p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# Seaborn is a library for making **``statistical graphics``** in Python. It **``builds on top of matplotlib``** and integrates closely with Ppandas data structures.
#
# Seaborn helps us explore and understand our data. Its plotting functions operate on **``DataFrames``** and **``arrays``** containing whole datasets and internally perform the necessary **``semantic mapping``** and **``statistical aggregation``** to produce informative plots. Its dataset-oriented, declarative API lets us focus on what the different elements of our plots mean, rather than on the details of how to draw them.
#
# - 🧐 **[An introduction to seaborn](https://seaborn.pydata.org/introduction.html)**,<br>
# - 🧐 **[seaborn: statistical data visualization](https://seaborn.pydata.org/)**,<br>
# - 🧐 **[Complete Seaborn Crash Course | Data Visualization in Seaborn (Youtube)](https://www.youtube.com/watch?v=GcXcSZ0gQps)**,<br>
# - 🧐 **[Seaborn Tutorial (Youtube)](https://www.youtube.com/watch?v=6GUZXDef2U0)**,<br>
# - 🧐 **[Seaborn Python Tutorial (Youtube)](https://www.youtube.com/watch?v=Pkvdc2Z6eBg)**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:125%; text-align:left;">👉 WARNING: In this notebook, instead of interpreting the output of the visualizations, we will try to understand how the visualization codes are created and modified. Interpretation is NOT the subject of the Visualization course but falls within the scope of the DAwPY course.</p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">CONTENT</p>
#
# * [MATPLOTLIB vs SEABORN](#0)
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#1)
# * [SEABORN PLOT TYPES](#2)
# * [Does Seaborn use Matplotlib? Connecting to Figure in Matplotlib.](#3)
#     * ["hue" Parameter](#3.1)
#     * ["size" Parameter](#3.2)
#     * ["style" Parameter](#3.3)
#     * ["alpha" Parameter](#3.4)
# * [EXPORTING (save) A SEABORN FIGURE](#4)
# * [RUGPLOT](#5)
# * [DISPLOT & HISTPLOT](#6)
# * [DISPLOT](#7)
# * [HISTPLOT](#8)
#     * [The Number of Bins in Histogram](#8.1)
#     * [Adding in a Grid & Styles](#8.2)
#     * [Adding in Keywords from Matplotlib](#8.3)
# * [THE KERNEL DENSITY ESTIMATION (KDE) PLOT](#9)
#     * [Cut Off KDE](#9.1)
#     * [Bandwidth](#9.2)
# * [2-DIMENSIONAL KDE PLOTS](#10)
# * [BONUS CODE FOR VISUALIZATIONS](#11)
#     * [What is dpi in Figure?](#11.1)
# * [SEABORN CHEAT SHEET](#12)
# * [THE END OF SEABORN SESSION 01](#13)

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">MATPLOTLIB vs SEABORN</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - ### 1.Functionality:
#
#   - **``Matplotlib:``** Matplotlib is mainly deployed for **``basic plotting``**. Visualization using Matplotlib generally consists of bars, pies, lines, scatter plots and so on.
#
#   - **``Seaborn:``** Seaborn, on the other hand, provides a variety of visualization patterns. It uses **``fewer syntax``** and has **``easily interesting default themes``**. It specializes in **``statistics visualization``** and is used if one has to summarize data in visualizations and also show the distribution in the data.
#
# - ### 2.Handling Multiple Figures:
#
#   - **``Matplotlib:``** Matplotlib has **``multiple figures``** that can be opened, but **``need to be closed explicitly``**. **``plt.close()``** only closes the current figure. **``plt.close(‘all’)``** would close them all.
#
#   - **``Seaborn:``** Seaborn **``automates``** the creation of **``multiple figures``**. This sometimes leads to **``OOM (out of memory) issues``**.
#
# - ### 3.Visualization:
#
#   - **``Matplotlib:``** Matplotlib is a graphics package for data visualization in Python. It is **``well integrated with NumPy and Pandas``**. The **``pyplot module``** mirrors the **``MATLAB``** plotting commands closely. Hence, MATLAB users can easily transit to plotting with Python.
#
#   - **``Seaborn:``** Seaborn is more integrated for working with **``Pandas DataFrames``**. It extends the Matplotlib library for creating beautiful graphics with Python using a **``more straightforward set of methods``*.
#
# - ### 4.Data frames and Arrays
#
#   - **``Matplotlib:``** Matplotlib **``works with DataFrames and arrays``**. It has different stateful APIs for plotting. The **``figures``** and **``axes``** are represented by the **``object``** and therefore plot() like calls without parameters suffices, without having to manage parameters.
#
#   - **``Seaborn:``** Seaborn **``works with the dataset as a whole``** and is **``much more intuitive than Matplotlib``**. For Seaborn, replot() is the entry API with ‘kind’ parameter to specify the type of plot which could be line, bar, or many of the other types. Seaborn is **`not stateful``**. Hence, plot() would require passing the object.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">👉 Now it's all about our choice and the type of requirement.</p>
#
#
# - 🧐 **[What do you prefer, Seaborn or Matplotlib? on Kaggle](https://www.kaggle.com/questions-and-answers/149640)**,<br>
# - 🧐 **[Matplotlib vs Seaborn on KD nuggets](https://www.kdnuggets.com/2019/04/data-visualization-python-matplotlib-seaborn.html)**,<br>
# - 🧐 **[Matplotlib vs Seaborn](https://analyticsindiamag.com/comparing-python-data-visualization-tools-matplotlib-vs-seaborn/)**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# 📝 **NOTE:** 📝	There is **NO need** to **import Matplotlib and Seaborn** libraries for plotting figures **in Pandas**. With a DataFrame, ``Pandas`` creates by default one line plot for each of the columns with numeric data.<br>
# Seaborn package is a Python data visualization library developed based on the Matplotlib library. Since ``Seaborn`` is built on ``Matplotlib`` they can be **used together**. ``Seaborn`` is used to create more **attractive and informative statistical graphics**. While Seaborn is a different package, it can also be used to develop the attractiveness of matplotlib graphics. When we load Seaborn into the session, everytime a Matplotlib is executed, Seaborn's default customizations are added.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">📝 ALWAYS REMEMBER 👉 There is NO need to import Matplotlib and Seaborn libraries for plotting figures in PANDAS.</p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
import pandas as pd  # DAwPy
import numpy as np   # DAwPy

import seaborn as sns                    # Stats-1 & DAwPy
from scipy import stats                  # Stats-1 & DAwPy
from scipy.stats import kurtosis, skew   # Stats-1 & DAwPy

import matplotlib                # DVwPy
import matplotlib.pyplot as plt  # DVwPy
#  magic command that allows for the inline display of plots within the notebook
# %matplotlib inline   

import warnings;
warnings.filterwarnings('ignore')
# This imports the warnings library and suppresses warnings that might be generated during the execution of the code. 
# This can help keep the output cleaner, especially during exploratory data analysis.

# %% [markdown]
# - **``Importing Libraries``**: Make sure to import the required libraries before beginning your analysis. You need both pandas and numpy.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# - ``import warnings``: This imports the warnings module, which is part of Python's standard library and provides a way to issue warning messages.
# - ``warnings.filterwarnings("ignore")``: This function call tells Python to ignore all warning messages that would normally be printed. This can be useful when we want to focus on the output of your program without being distracted by warnings.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>📢 Caution ❗❗❗</strong></p>
#
#
# - Ignoring warnings can sometimes hide important issues in our code, so use this approach judiciously. It's generally better to address the underlying causes of warnings rather than suppressing them.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Before going further, let's explore which versions of the libraries will be used in this analysis :**

# %%
import pandas as pd    # DAwPy
import numpy as np     # DAwPy
import seaborn as sns  # Stats-1 & DAwPy
import matplotlib      # Stats-1 & DAwPy
import scipy           # Stats-1 & DAwPy

# Print the versions of the libraries
print("Pandas version:", pd.__version__)             
print("NumPy version:", np.__version__)                
print("Seaborn version:", sns.__version__)            
print("Matplotlib version:", matplotlib.__version__) 
print("Scipy version:", scipy.__version__)
# Out:
# Pandas version: 2.1.1
# NumPy version: 1.24.3
# Seaborn version: 0.13.2
# Matplotlib version: 3.7.2
# Scipy version: 1.11.1

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:140%; text-align:left;"><strong>👉 Behind the scenes, ``Seaborn uses matplotlib`` to draw its plots 😱:</strong></p>

# %%
# Let us remember the built-in datasets in Seaborn library

print("There been", len(sns.get_dataset_names()), "built-in datasets in Seaborn library.")
print()
print(sns.get_dataset_names())
# Out:
# There been 22 built-in datasets in Seaborn library.
#
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [raw]
# Previously, there had been 88 built-in datasets in Seaborn library.
#
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Loading Tips Dataset from Seaborn:</strong></p>
#
#
# **The following command ``fetches the "tips"`` dataset from ``Seaborn``, which is a popular library for statistical data visualization in Python. This dataset contains ``information about restaurant tips`` and includes various features related to ``customer behavior``.**

# %%
# Let's load "tips" built-in dataset at Seaborn and assign it as "tips"

# Load the tips dataset
tips = sns.load_dataset("tips")  # fetch the "tips" dataset in the Seaborn

# Display the first five rows
tips.head()  # returns the first five rows of the DataFrame
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# The **``"tips"``** dataset typically includes the following **``columns``**:
#
# - **``total_bill``**: The total bill amount (in dollars).
# - **``tip``**: The tip amount (in dollars).
# - **``sex``**: The gender of the person paying the bill (either "Male" or "Female").
# - **``smoker``**: Indicates whether the person is a smoker ("Yes" or "No").
# - **``day``**: The day of the week when the dining occurred (e.g., "Thur", "Fri", "Sat", "Sun").
# - **``time``**: The time of day (either "Lunch" or "Dinner").
# - **``size``**: The size of the dining party (number of people).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">SEABORN PLOT TYPES</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Seaborn offers a **``diverse range of plotting types``** that can be categorized into three main groups:
# - **``distribution``**,
# - **``categorical``**, and
# - **``comparison``** plots.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# - **``Distribution plots``** visualize the **``spread and shape of data``**, with options like **``histograms``**, **``KDE plots``**, and **``box plots``**.
# - **``Categorical plots``** allow for the analysis of **``categorical data``** through **``bar plots``**, **``count plots``**, and **``point plots``** to compare groups.
# - Finally, **``comparison plots``** facilitate the examination of **``relationships between variables``**, featuring **``scatter plots``**, **``facet grids``**, and **``heatmaps``**.
#
# Together, these tools empower users to conduct insightful exploratory data analysis and visualize complex datasets effectively.
#
#
#
# <img src=https://i.ibb.co/Q9SXCR1/Capture12.png width="600" height="200">

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# #### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">How to change a figure's size in Python Seaborn package?</p>
#
# In Seaborn, we can change a figure's size using the **``plt.figure()``** function from Matplotlib or by setting the **``figsize``** parameter within the plotting functions.
# - **``For a Single Cell:``**
#   - We can set the figure size directly in a specific plotting cell using **``plt.figure(figsize=(width, height))``**.
#     - ``plt.figure(figsize=(12, 6))``  # Width = 12, Height = 6
# - **``For the Whole Notebook:``**
#   - To set the default figure size for all plots in a notebook, we can use the **``set_context()``** function OR **``set the rcParams``** in Matplotlib. Here are two methods:
#     - Method 1: Using set_context()
#       - ``sns.set_context("notebook", rc={"figure.figsize": (12, 6)})``  # Default size for all plots
#     - Method 2: Using rcParams
#       - ``plt.rcParams["figure.figsize"] = (12, 6)``  # Width = 12, Height = 6
#
#
# [SOURCE](https://stackoverflow.com/questions/33446029/how-to-change-a-figures-size-in-python-seaborn-package)

# %%
# plt.figure(figsize=(12, 8))  # Creates a new figure with the specified size and 
                               # Only affects the current figure being created 

# Both set the default figure size for all plots to 12 inches by 8 inches
# Both affect all figures created after this setting in the current session until you change it again or reset it
# plt.rcParams['figure.figsize']=(12, 8)  # adjust the default settings for subsequent plots
# sns.set(rc={'figure.figsize':(12, 8)})  # adjust the default settings for subsequent plots


# g=sns.pairplot()  # Initializes a pair plot, but it needs a dataset to work with
# g.fig.set_size_inches(12, 8)  # Sets the size of the figure for the pair plot to 12 inches by 8 inches
                                # Adjusts the size of an existing figure

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>📢 Caution ❗❗❗</strong></p>
#
#
# The commands **``plt.figure(figsize=(12, 8))``** and **``plt.rcParams['figure.figsize'] = (12, 8)``** in Matplotlib serve different purposes in managing figure sizes.
# - The **``former``** creates a specific figure with the designated dimensions, **``applying only to that figure``** and **``NOT affecting subsequent plots``**.
# - In contrast, the **``latter``** sets a **``default figure size for ALL plots``** created **``in the current session``**, ensuring consistency across visualizations until changed.
#
# Thus, the **``first command``** offers **``localized control``**, while the **``second``** provides a **``global setting``** for figure dimensions.
#
# <hr>
#
#
# **matplotlib.rcParams** contains some **``properties``** in **``matplotlibrc``** file. We can use it to **``control the defaults``** of almost every property in Matplotlib: ``figure size`` and ``DPI``, ``line width``, ``color`` and ``style``, ``axes``, ``axis`` and ``grid`` properties, ``text`` and ``font`` properties and so on. In order to use matplotlib.rcParams, we should know what properties are stored in it, these **``properties can be foud in matplotlibrc file``** 🧐 **[The list of rcParams](https://matplotlib.org/stable/api/matplotlib_configuration_api.html)**.
#
# **``Seaborn``** has **``default congurations``** that can be applied with **sns.set()**. It **``uses the matplotlib rcParam system``** and will affect how all matplotlib plots look, even if we don’t make them with seaborn. Beyond the default theme, there are several other options, and we can independently control the style.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <img src=https://i.ibb.co/n0WsYB1/seaborn-scatterplot.png width="600" height="200">
#
#
# **``Scatter plots``** can show how different features are related to one another, the main theme between all relational plot types is they display **``how features are interconnected to each other``**. There are many different types of plots that can be used to show this, so let's explore the **[seaborn.scatterplot()](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)** as well as general seaborn parameters applicable to other plot types.
#
# - 🧐 **[Scatterplot with multiple semantics](https://seaborn.pydata.org/examples/different_scatter_variables.html)**,<br>
# - 🧐 **[7 Points to Create Better Scatter Plots with Seaborn](https://towardsdatascience.com/7-points-to-create-better-scatter-plots-with-seaborn-9f0202fb2ba4)**,<br>
# - 🧐 **[Basic Scatterplot with Seaborn](https://www.python-graph-gallery.com/40-basic-scatterplot-seaborn)**,<br>
# - 🧐 **[Seaborn Scatter Plot](https://www.educba.com/seaborn-scatter-plot/)**,<br>
# - 🧐 **[Introduction to Seaborn Scatter Plot](https://www.naukri.com/learning/articles/introduction-to-seaborn-scatter-plot/)**,<br>
# - 🧐 **[Data Visualization With Seaborn](https://medium.com/@nutanbhogendrasharma/data-visualization-with-seaborn-part-1-1f4743274753)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet is used to ``embed a YouTube video within a Jupyter Notebook`` using the IPython.display module.**

# %%
from IPython.display import YouTubeVideo

# Embed the YouTube video
YouTubeVideo('4yz4cMXCkuw', width=800, height=500)

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Docstring of scatterplot()</strong></p>

# %% [raw]
# sns.scatterplot(
#                 *,
#                 x=None,
#                 y=None,
#                 hue=None,
#                 style=None,
#                 size=None,
#                 data=None,
#                 palette=None,
#                 hue_order=None,
#                 hue_norm=None,
#                 sizes=None,
#                 size_order=None,
#                 size_norm=None,
#                 markers=True,
#                 style_order=None,
#                 x_bins=None,
#                 y_bins=None,
#                 units=None,
#                 estimator=None,
#                 ci=95,
#                 n_boot=1000,
#                 alpha=None,
#                 x_jitter=None,
#                 y_jitter=None,
#                 legend='auto',
#                 ax=None,
#                 **kwargs,
#                 )
# Docstring:
# Draw a scatter plot with possibility of several semantic groupings.
#
# The relationship between ``x`` and ``y`` can be shown for different subsets of the data using the ``hue``, ``size``, and ``style`` parameters. These parameters control what visual semantics are used to identify the different subsets. It is possible to show up to three dimensions independently by using all three semantic types, but this style of plot can be hard to interpret and is often ineffective. Using redundant semantics (i.e. both ``hue`` and ``style`` for the same variable) can be helpful for making graphics more accessible.
#
# See the :ref:`tutorial <relational_tutorial>` for more information.
#
# The default treatment of the ``hue`` (and to a lesser extent, ``size``) semantic, if present, depends on whether the variable is inferred to represent "numeric" or "categorical" data. In particular, numeric variables are represented with a sequential colormap by default, and the legend entries show regular "ticks" with values that may or may not exist in the
# data. This behavior can be controlled through various parameters, as described and illustrated below.
#
# Parameters
# ----------
# x, y : vectors or keys in ``data``
#     Variables that specify positions on the x and y axes.
# hue : vector or key in ``data``
#     Grouping variable that will produce points with different colors.
#     Can be either categorical or numeric, although color mapping will behave differently in latter case.
# size : vector or key in ``data``
#     Grouping variable that will produce points with different sizes.
#     Can be either categorical or numeric, although size mapping will behave differently in latter case.
# style : vector or key in ``data``
#     Grouping variable that will produce points with different markers.
#     Can have a numeric dtype but will always be treated as categorical.
# data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence
#     Input data structure. Either a long-form collection of vectors that can be assigned to named variables or a wide-form
#     dataset that will be internally
#     reshaped.
# palette : string, list, dict, or :class:`matplotlib.colors.Colormap`
#     Method for choosing the colors to use when mapping the ``hue`` semantic.
#     String values are passed to :func:`color_palette`. List or dict values imply categorical mapping, while a colormap object
#     implies numeric mapping.
# hue_order : vector of strings
#     Specify the order of processing and plotting for categorical levels of the ``hue`` semantic.
# hue_norm : tuple or :class:`matplotlib.colors.Normalize`
#     Either a pair of values that set the normalization range in data units or an object that will map from data units into a
#     [0, 1] interval. Usage implies numeric mapping.
# sizes : list, dict, or tuple
#     An object that determines how sizes are chosen when ``size`` is used.
#     It can always be a list of size values or a dict mapping levels of the ``size`` variable to sizes. When ``size``  is
#     numeric, it can also be a tuple specifying the minimum and maximum size to use such that other values are normalized within
#     this range.
# size_order : list
#     Specified order for appearance of the ``size`` variable levels,
#     otherwise they are determined from the data. Not relevant when the ``size`` variable is numeric.
# size_norm : tuple or Normalize object
#     Normalization in data units for scaling plot objects when the
#     ``size`` variable is numeric.
# markers : boolean, list, or dictionary
#     Object determining how to draw the markers for different levels of the ``style`` variable. Setting to ``True`` will use
#     default markers, or you can pass a list of markers or a dictionary mapping levels of the ``style`` variable to markers.
#     Setting to ``False`` will draw marker-less lines.  Markers are specified as in matplotlib.
# style_order : list
#     Specified order for appearance of the ``style`` variable levels otherwise they are determined from the data. Not relevant
#     when the ``style`` variable is numeric.
# {x,y}_bins : lists or arrays or functions
#     *Currently non-functional.*
# units : vector or key in ``data``
#     Grouping variable identifying sampling units. When used, a separate line will be drawn for each unit with appropriate
#     semantics, but no legend entry will be added. Useful for showing distribution of experimental replicates when exact
#     identities are not needed.
#     *Currently non-functional.*
# estimator : name of pandas method or callable or None
#     Method for aggregating across multiple observations of the ``y``variable at the same ``x`` level. If ``None``, all
#     observations will be drawn.
#     *Currently non-functional.*
# ci : int or "sd" or None
#     Size of the confidence interval to draw when aggregating with an estimator. "sd" means to draw the standard deviation of the
#     data. Setting to ``None`` will skip bootstrapping. *Currently non-functional.*
# n_boot : int
#     Number of bootstraps to use for computing the confidence interval. *Currently non-functional.*
# alpha : float
#     Proportional opacity of the points.
# {x,y}_jitter : booleans or floats
#     *Currently non-functional.*
# legend : "auto", "brief", "full", or False
#     How to draw the legend. If "brief", numeric ``hue`` and ``size``
#     variables will be represented with a sample of evenly spaced values.
#     If "full", every group will get an entry in the legend. If "auto", choose between brief or full representation based on
#     number of levels.
#     If ``False``, no legend data is added and no legend is drawn.
# ax : :class:`matplotlib.axes.Axes`
#     Pre-existing axes for the plot. Otherwise, call :func:`matplotlib.pyplot.gca` internally.
# kwargs : key, value mappings
#     Other keyword arguments are passed down to
#     :meth:`matplotlib.axes.Axes.scatter`.
#
# Returns
# -------
# :class:`matplotlib.axes.Axes`
#     The matplotlib axes containing the plot.
#
# See Also
# --------
# lineplot : Plot data using lines.
# stripplot : Plot a categorical scatter with jitter.
# swarmplot : Plot a categorical scatter with non-overlapping points.

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Basic Scatter Plot with Seaborn:</strong></p>
#
#
# **In Seaborn, the ``figsize`` parameter CANNOT be directly passed to the sns.scatterplot() function. Instead, we should set the figure size using Matplotlib's ``plt.figure()`` before creating the plot.**

# %%
# Create the scatter plot

sns.scatterplot(x='total_bill', y='tip', data=tips);  # NO figsize=(12, 8) CANNOT work as a parameter.

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating Scatter Plot Using figsize parameter from Matplotlib:</strong></p>
#
#
# **The following code sets up a scatter plot using Seaborn's scatterplot function after specifying the figure size with Matplotlib's plt.figure().**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;">📢 Caution: There is NO figsize parameter in Seaborn methods BUT we can utilize Matplotlib attributes❗❗❗</p>

# %%
# Set the figure size
plt.figure(figsize=(10, 6))  # Creates a new figure with the specified size

# Create the scatter plot
sns.scatterplot(x='total_bill', y='tip', data=tips); 

# Only affects the current figure being created

# %% [markdown]
# - **``plt.figure(figsize=(12, 8))``**: This sets the size of the figure to 12 inches wide and 8 inches tall.
# - **``sns.scatterplot(...)``**: This creates the scatter plot using the specified x and y variables from the dataset.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Setting the Figure Size by RC Params:</strong></p>
#
# - **[Customizing Matplotlib with style sheets and rcParams](https://matplotlib.org/stable/users/explain/customizing.html)**
#
#
# **The following code sets a ``default figure size for all subsequent plots`` using Seaborn's set() function.**

# %%
# rc -- > Run Configuration

# Affect all figures created after this setting in the current session until we change it again or reset it
sns.set(rc={'figure.figsize':(10, 6)})  # specifies the default figure size for all subsequent plots

# Create the scatter plot
sns.scatterplot(x='total_bill', y='tip', data=tips);

# %% [markdown]
# - **``sns.set(rc={'figure.figsize': (10, 6)}):``**
#   - This command sets the default figure size for all subsequent plots to 10 inches wide and 6 inches tall. The change will persist throughout the current session until modified again or reset.
# - **``sns.scatterplot(x='total_bill', y='tip', data=tips):``**
#   - This creates a scatter plot using the tips dataset, where the x-axis represents the total bill amounts and the y-axis represents the tips given.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Setting the Figure Size and Background Style:</strong></p>
#
#
# **The following code sets both the default figure size and the style for all subsequent plots using Seaborn.**

# %%
sns.set(rc={'figure.figsize':(10, 6)}, style='white')  # specifies the default figure size and style for all subsequent plots

# Create the scatter plot
sns.scatterplot(x=tips['total_bill'], y=tips['tip']);

# %% [markdown]
# - **``sns.set(rc={'figure.figsize': (10, 6)}, style='white'):``**
#   - This command configures Seaborn to set the default figure size to 10 inches wide and 6 inches tall. The style parameter is set to 'white', which gives the plots a clean, minimalistic look by using a white background.
# - **``sns.scatterplot(x=tips['total_bill'], y=tips['tip']):``**
#   - This creates a scatter plot where the x-axis represents the total bill amounts and the y-axis represents the tips given, using the tips dataset.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 RC Params sets Figure Size and Background Style throughout the Session:</strong></p>

# %%
# It still keeps plotting figsize=(10, 6)

sns.scatterplot(x=tips['total_bill'], y=tips['tip']);

# %% [markdown]
# When we set the figure size using sns.set(rc={'figure.figsize': (10, 6)}), it applies to all subsequent plots in the session, including the scatter plot we create later. Therefore, we do **``NOT need to specify figsize again for individual plots after this setting``**.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>🤔💭 How to restore all RC params to default settings❓</strong></p>
#
#
# **To ``restore all Seaborn RC parameters to their default settings``, we can use the ``sns.reset_orig()`` and ``sns.set_context("notebook")`` functions in Seaborn or ``plt.rcdefaults()`` in Matplotlib. The first two functions reset the Seaborn configuration back to the original Matplotlib defaults, effectively undoing any changes made to the style and figure settings.**

# %%
# matplotlib.rc_file_defaults()
# sns.reset_defaults()  # To return into default properties

# Restore all Seaborn RC parameters to their default settings
sns.reset_orig()  # To return into default properties
# Optional: Ensure inline plotting in Jupyter Notebooks
# %matplotlib inline   

# Create a scatter plot again, now with default settings
sns.scatterplot(x=tips['total_bill'], y=tips['tip']);

# %% [markdown]
# - **``sns.reset_orig():``**
#   - This function resets all Seaborn settings to their original Matplotlib defaults, removing any custom styles or sizes you previously set.
# - **``%matplotlib inline:``**
#   - This magic command is specific to Jupyter Notebooks. It ensures that plots are displayed inline within the notebook.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">👉 After resetting, any new plots will use the default settings, which means they won't have the custom styles or sizes we previously defined.</p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Does Seaborn use Matplotlib? Connecting to Figure in Matplotlib.</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ``Seaborn`` is a high-level library. It provides simple codes to visualize complex statistical plots, which also happen to be aesthetically pleasing. But ``Seaborn`` was built on top of Matplotlib, meaning it can be further powered up with Matplotlib functionalities.
#
# 🤔 ❓ **[Seaborn can do the job, then why Matplotlib?](https://towardsdatascience.com/seaborn-can-do-the-job-then-why-matplotlib-dac8d2d24a5f)** 🤔 ❓
#
# 📝 **Note:** 📝 How matplotlib is still connected to seaborn underneath (even without importing matplotlib.pyplot), since ``Seaborn`` itself is directly making a Figure call with matplotlib. We can import matplotlib.pyplot and make calls to directly effect the Seaborn figure.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with Seaborn and Set Figure Size with Matplotlib:</strong></p>

# %%
# Create a figure with specified size
plt.figure(figsize=(12, 8))  # initializes a new figure with a size of 12 inches wide and 8 inches tall

# Create a scatter plot
sns.scatterplot(x='total_bill', y='tip', data=tips);  # identify any potential correlation between the total bill and the tip amount

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">"hue" Parameter</p>
#
# <a id="3.1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# In Seaborn, the **``hue``** parameter determines **``which column``** in the DataFrame should be **``used for colour encoding``**. So, **``hue``** parameter colors observations based off a categorical feature in the DataFrame. It can be either categorical or numeric, although color mapping will behave differently in latter case.
#
# 🧐 **[seaborn.scatterplot (Official Webpage)](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)**,<br>
# 🧐 **[Scatterplot with varying point sizes and hues](https://seaborn.pydata.org/examples/scatter_bubbles.html)**,<br>
# 🧐 **[What is the significance of hue parameter in seaborn plotting?](https://datascience.stackexchange.com/questions/46117/meaning-of-hue-in-seaborn-barplot)**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with Hue parameter:</strong></p>

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips);

# %%
# Create a scatter plot with gender differentiation (hue)

sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex");

# Hue parameter adds color differentiation to the points based on the "sex" variable, 
# allowing you to distinguish between male and female customers in the plot.

# %% [markdown]
# - **``hue="sex"``**: Colors the points based on the sex column in the dataset, allowing for differentiation between male and female diners.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">"size" vs "s" Parameters</p>
#
# <a id="3.2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Both **``size``** and **``s``** parameters relate to the size of the markers (points) in the plot, but they **``serve different purposes``**:
#
# - **``size``** parameter allows us to **``size based on another column``**. It groups variable that will **``produce points with different sizes``**. It can be either **``categorical``** or **``numeric``**, although size mapping will behave differently in latter case. Size parameter maps marker sizes to a variable in the dataset, allowing for a **``dynamic representation of data across different points``**.
# - On the other hand **``s``** parameter **``sets a static size for all markers``**, making it easier to control the appearance of the plot without regard to data values. The **``s``** parameter in Seaborn's plotting functions is designed for **``continuous variables``**.
#
# **``size`` Parameter:**
# - **``Purpose``**: The **``size``** parameter is used to map the sizes of the markers to a variable in our dataset.
# - **``Type``**: Typically expects a **``continuous numerical variable``**.
# - **``Functionality``**: When we specify a variable for size, Seaborn will scale the marker sizes based on the values in that variable. This allows for a visual representation of another dimension of data.
# - **``Example Use Case``**: We might want to represent the size of the markers based on the total number of people in a group (e.g., size='size').
#   - **``Example``**: ``sns.scatterplot(x='total_bill', y='tip', data=tips, size='size', sizes=(20, 200));``
#
# **``s`` Parameter:**
# - **``Purpose``**: The **``s``** parameter is used to set a **``fixed size``** for all markers in the scatter plot.
# - **``Type``**: Expects a **``numerical value``** (or an array of numerical values for individual sizes).
# - **``Functionality``**: It defines the size of the markers uniformly across the plot, meaning **``all points will be the same size``** unless specified otherwise.
# - **``Example Use Case``**: We may want all points to be larger for better visibility, regardless of any data variable.
#   - **``Example``**: ``sns.scatterplot(x='total_bill', y='tip', data=tips, s=100);``  # All points have the same size of 100
#
#
# - 🧐 **[seaborn.scatterplot (Official Webpage)](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)**,<br>
# - 🧐 **[Scatterplot with varying point sizes and hues](https://seaborn.pydata.org/examples/scatter_bubbles.html)**,<br>
# - 🧐 **[Set Marker Size in Seaborn Scatterplots](https://www.delftstack.com/howto/seaborn/scatterplot-marker-size-seaborn/)**,<br>
# - 🧐 **[seaborn scatterplot marker size for ALL markers](https://stackoverflow.com/questions/52785101/seaborn-scatterplot-marker-size-for-all-markers)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with Hue and s parameters:</strong></p>

# %%
# Create a scatter plot with larger points (s) and gender differentiation (hue)

sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex", s=200);

# s=200: Sets the size of the points in the scatter plot to 200, making them larger and more visually prominent.

# %% [markdown]
# - **``hue="sex"``**: This parameter colors the points based on the sex column, allowing you to differentiate between male and female diners in the plot.
# - **``s=200``**: This sets the size of the scatter plot markers to 200, making them larger and easier to see.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">"style" Parameter</p>
#
# <a id="3.3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Automatically choose styles based on another categorical feature in the dataset. Optionally use the **markers** parameter to pass a list of marker choices based off matplotlib, for example: ['*', '+', 'o']
#
# 🧐 **[seaborn.scatterplot](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)**,<br>
# 🧐 **[Seaborn Styling, Part 1: Figure Style and Scale](https://www.codecademy.com/article/seaborn-design-i)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Let us remember our "tips" dataset

tips.head()  # returns the first five rows of the DataFrame
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with style parameter:</strong></p>

# %%
# Create a scatter plot with different marker styles for gender (intended for Categorical variables)

sns.scatterplot(x="total_bill", y="tip", data=tips, style="sex");

# style="sex": Differentiates the points by the "sex" variable, using different marker styles for male and female customers 
# (e.g., circles for one gender and cross sign for another).

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex", style="sex");

# %% [markdown]
# - **``style="sex"``**: This parameter differentiates the markers based on the sex column in the dataset. **``Different marker styles``** will be used for **``male``** and **``female``** diners, allowing for a clear visual distinction.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with size parameter:</strong></p>

# %%
# Create a scatter plot with size based on gender (note: this may not behave as expected)

sns.scatterplot(x='total_bill', y='tip', data=tips, size="sex");

# size="sex": This parameter attempts to differentiate the sizes of the points based on the "sex" variable. 
# However, since "sex" is categorical, this might not behave as expected. Typically, size is used for continuous numerical values rather than categorical ones.

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>📢 Important Note ❗❗❗</strong></p>
#
#
# - Using **``size="sex"``** may **``NOT produce a meaningful visualization``** since **``"sex"``** is **``categorical``**. If we want to differentiate points based on gender, we might consider using the **``hue``** parameter instead, which colors the points based on gender:
#
#   - <code>sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex');</code>
#
# <hr>
#
# - **``Size Parameter``**: The size parameter is generally intended for continuous variables. Using a categorical variable like "sex" may not yield the expected result.
# - **``Visual Differentiation``**: For categorical differentiation, hue is typically the better option, as it allows for clear color-coding of different categories.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Create a scatter plot with gender differentiation (hue) and larger points (s)

sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex", s=200);

# %% [markdown]
# - **``hue="sex"``**: Differentiates the points by the "sex" variable, coloring them based on whether the customer is male or female.
# - **``s=200``**: Sets the size of the points in the scatter plot to 200, making them larger and more visually prominent.
#
#    - **``Continuous Variable``**: The s parameter is suitable for continuous variables when you want to represent the size of the markers based on their values.
#    - **``Static Size``**: If we provide a single value, it will set a uniform size for all markers regardless of any data variable.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with hue and size parameters:</strong></p>

# %%
# Create a scatter plot with sizes based on party size and color differentiation by gender

sns.scatterplot(x='total_bill', y='tip', data=tips, hue="sex", size='size', sizes=(20, 200));  
# Size will designed based on 'size' column

# %% [markdown]
# - **``hue="sex"``**: Differentiates the points by the "sex" variable, coloring them based on whether the customer is male or female.
# - **``size='size'``**: This uses the **``size column``** to determine the size of the markers. The sizes parameter controls the range of sizes.
# - **``sizes=(20, 200)``**: This sets the **``minimum and maximum sizes for the markers``**, ensuring they are appropriately scaled for visibility.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with hue, s, and style parameters:</strong></p>

# %%
# Create a scatter plot with color (hue) and style differentiation with fixed size by gender (s and style)

sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex", s=200, style="sex");

# %% [markdown]
# - **``hue="sex"``**: Differentiates the points by color based on the "sex" variable, allowing you to visually distinguish between male and female customers.
# - **``s=200``**: Sets a fixed uniform size of 200 for all markers, making them larger and easier to see.
# - **``style="sex"``**: Differentiates the points by marker style based on the "sex" variable, using different shapes (e.g., circles for one gender and squares for another).
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with hue, s, and style parameters:</strong></p>

# %%
# Create a scatter plot with color (hue) and style differentiation with fixed size by smoker (s and style)

sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex", s=200, style="smoker");

# %% [markdown]
# - **``hue="sex"``**: Differentiates the points by color based on the "sex" variable, allowing you to visually distinguish between male and female customers.
# - **``s=200``**: Sets a fixed size of 200 for all markers, making them larger and easier to see.
# - **``style="smoker"``**: Differentiates the points by marker style based on the "smoker" variable, using different shapes (e.g., circles for non-smokers and squares for smokers).
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with hue, s, and style parameters:</strong></p>

# %%
# Create a scatter plot with color (hue) and style differentiation with fixed size by day of the week (s and style)

sns.scatterplot(x="total_bill", y="tip", data=tips, hue="day", s=200, style="day");

# %% [markdown]
# - **``hue="day"``**: Differentiates the points by color based on the "day" variable, allowing you to visually distinguish between different days of the week.
# - **``s=200``**: Sets a fixed size of 200 for all markers, making them larger and easier to see.
# - **``style="day"``**: Differentiates the points by marker style based on the "day" variable, using different shapes for each day of the week.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with hue, s, and style parameters:</strong></p>

# %%
# Creates a new figure with the specified size
plt.figure(figsize=(12, 8))

# Create a scatter plot with color differentiation by day and style by gender
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="day", s=200, style="sex");

# %% [markdown]
# - **``hue="day"``**: Differentiates the points by color based on the "day" variable, allowing you to visually distinguish between different days of the week.
# - **``s=200``**: Sets a fixed size of 200 for all markers, making them larger and easier to see.
# - **``style="sex"``**: Differentiates the points by marker style based on the "sex" variable, using different shapes for male and female customers.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with hue, style. size, and s parameters:</strong></p>

# %%
# Creates a new figure with the specified size
plt.figure(figsize=(12, 8))

sns.scatterplot(x="total_bill", y="tip", data=tips, hue="day", style="sex", size="smoker", s=200);

# %% [markdown]
# - **``hue="day"``**: Differentiates the points by color based on the "day" variable, allowing you to visually distinguish between different days of the week.
# - **``style="sex"``**: Differentiates the points by marker style based on the "sex" variable, using different shapes for male and female customers.
# - **``size="smoker"``**: This parameter attempts to map the sizes of the markers based on the "smoker" variable. However, since "smoker" is categorical, this may not produce meaningful results unless properly handled (e.g., mapping to specific sizes).
# - **``s=200``**: Sets a base size for all markers, which may be overridden by the size mapping.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">"alpha" Parameter</p>
#
# <a id="3.4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - Proportional opacity of the points.
#
# To **``control the transparency``** of plots, we can use the **``alpha``** argument within the plot function. **``By default``**, its value is **``1``**. The value of this parameter ranges from 0 to 1, with the plot getting more transparent and **``invisible as the value reaches 0``**. It can be used directly in most of the plot functions of the seaborn module.
#
# - 🧐 **[seaborn.scatterplot](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)**,<br>
# - 🧐 **[Transparency of Seaborn Plots](https://www.delftstack.com/howto/seaborn/seaborn-plots-transparency/)**,<br>
# - 🧐 **[Adjust different transparency for different class in seaborn scatter plot](https://stackoverflow.com/questions/54389331/adjust-different-transparency-for-different-class-in-seaborn-scatter-plot)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with s and alpha parameters:</strong></p>

# %%
# Create a scatter plot with specified size and transparency

sns.scatterplot(x='total_bill', y='tip', data=tips, s=200, alpha=0.6);  # An alpha value of 0.2 means the markers will be quite transparent

# %% [markdown]
# - **``s=200``**: Sets a fixed size of 200 for all markers, making them larger and easier to see.
# - **``alpha=0.2``**: Sets the transparency of the markers. An alpha value of 0.2 means the markers will be quite transparent, allowing overlapping points to be seen more clearly.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">EXPORTING (save) A SEABORN FIGURE</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - To save a plot in Seaborn, we can use the** **``savefig()``** **method.
#
# **``Matplotlib.pyplot.savefig()``**<br>
# - As the name suggests **``savefig()``** method is used to **``save the figure created after plotting data``**. The figure created can be saved to our local machines by using this method.
#
#   - **Syntax:** savefig(fname, dpi=None, facecolor=’w’, edgecolor=’w’, orientation=’portrait’, papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with style, hue, and s parameters and Saving the Output into Current Directory:</strong></p>

# %%
# Create a figure with specified size
plt.figure(figsize=(12, 8))

# Create a scatter plot with differentiation by gender
sns.scatterplot(x='total_bill', y='tip', data=tips, style='sex', hue='sex', s=100);

# Save the figure as a JPEG file
# Call savefig in the same cell
plt.savefig('seaborn_example_scatter.jpg')

# %% [markdown]
# - **``style='sex'``**: This parameter differentiates the markers based on the sex column, allowing for different marker styles (e.g., different shapes) for male and female diners.
# - **``hue='sex'``**: This colors the points based on the sex column, providing another layer of differentiation between male and female diners.
# - **``s=100``**: This sets the size of the scatter plot markers to 100, making them moderately visible.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# - **``plt.savefig('example_scatter.jpg')``**: This saves the current figure to a file named example_scatter.jpg.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet is used to ``embed a YouTube video within a Jupyter Notebook`` using the IPython.display module.**

# %%
from IPython.display import YouTubeVideo

# Embed the YouTube video
YouTubeVideo('S12WV-NoCNQ', width=800, height=500)

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">RUGPLOT</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# A rugplot is a graph that places **a dash horizontally with each occurrence of an item** in a dataset. Areas where there is **great occurrence of an item** see **a greater density of these dashes**. Areas where there is **little occurrence of an item** see just **occasional dashes**. This is the essence of a rugplot.<br>
# Seaborn already has built-in data sets. A rug plot is a plot of data for a single quantitative variable, displayed as marks along an axis. **Rug plots are often used in combination with two-dimensional scatter plots** by placing a rug plot of the x values of the data along the x-axis, and similarly for the y values.
#
# - Plot marginal distributions by drawing ticks along the x and y axes.
#
# This function is intended to complement other plots by showing the location of individual observations in an unobstrusive way.
#
# - 🧐 **[seaborn.rugplot](https://seaborn.pydata.org/generated/seaborn.rugplot.html)**,<br>
# - 🧐 **[How to Create a Rugplot in Seaborn with Python](http://www.learningaboutelectronics.com/Articles/How-to-create-a-rugplot-in-seaborn-with-Python.php)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>🤔💭 What is a Rug Plot in Python Seaborn and How to Create it❓</strong></p>
#
#
# **The following code snippet is used to ``embed a YouTube video within a Jupyter Notebook`` using the IPython.display module.**

# %%
from IPython.display import YouTubeVideo

# Embed the YouTube video
YouTubeVideo('Io-Ew7bWbcU', width=800, height=500)

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Docstring of rugplot()</strong></p>

# %% [raw]
# sns.rugplot(
#             x=None,
#             *,
#             height=0.025,
#             axis=None,
#             ax=None,
#             data=None,
#             y=None,
#             hue=None,
#             palette=None,
#             hue_order=None,
#             hue_norm=None,
#             expand_margins=True,
#             legend=True,
#             a=None,
#             **kwargs,
#             )
# Docstring:
# Plot marginal distributions by drawing ticks along the x and y axes.
#
# This function is intended to complement other plots by showing the location of individual observations in an unobstrusive way.
#
# Parameters
# ----------
# x, y : vectors or keys in ``data``
#     Variables that specify positions on the x and y axes.
# height : number
#     Proportion of axes extent covered by each rug element.
# axis : {"x", "y"}
#     Axis to draw the rug on.
#
#     .. deprecated:: 0.11.0
#        specify axis by assigning the ``x`` or ``y`` variables.
#
# ax : :class:`matplotlib.axes.Axes`
#     Pre-existing axes for the plot. Otherwise, call :func:`matplotlib.pyplot.gca` internally.
# data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence
#     Input data structure. Either a long-form collection of vectors that can be assigned to named variables or a wide-form
#     dataset that will be internally reshaped.
# hue : vector or key in ``data``
#     Semantic variable that is mapped to determine the color of plot elements.
# palette : string, list, dict, or :class:`matplotlib.colors.Colormap`
#     Method for choosing the colors to use when mapping the ``hue`` semantic.
#     String values are passed to :func:`color_palette`. List or dict values imply categorical mapping, while a colormap object
#     implies numeric mapping.
# hue_order : vector of strings
#     Specify the order of processing and plotting for categorical levels of the ``hue`` semantic.
# hue_norm : tuple or :class:`matplotlib.colors.Normalize`
#     Either a pair of values that set the normalization range in data units or an object that will map from data units into a
#     [0, 1] interval. Usage implies numeric mapping.
# expand_margins : bool
#     If True, increase the axes margins by the height of the rug to avoid overlap with other elements.
# legend : bool
#     If False, do not add a legend for semantic variables.
# kwargs
#     Other keyword arguments are passed to :meth:`matplotlib.collections.LineCollection`
#
# Returns
# -------
# :class:`matplotlib.axes.Axes`
#     The matplotlib axes containing the plot.

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Rug Plot with Seaborn:</strong></p>
#
# **The following line of code creates a ``rug plot`` using Seaborn, which visualizes the ``distribution of the total_bill amounts`` in the tips dataset.**

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# Create a rug plot for total bill

sns.rugplot(tips['total_bill']);

# Rug Plot adds small vertical lines (or "ticks") at each data point along the x-axis, which helps visualize the distribution of the data.

# %% [markdown]
# sns.rugplot() is a function in Seaborn that adds small vertical lines (or "rug" marks) along the x-axis for each data point in the specified variable. This visualization helps to depict the distribution of data points along a single dimension.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Rug Plot with Seaborn:</strong></p>
#
#
# **The following line of code creates a ``rug plot`` using Seaborn to visualize the ``distribution of the tip amounts`` from the tips dataset.**

# %%
# Create a rug plot for tip

sns.rugplot(tips['tip']);

# %% [markdown]
# **🚨🚨🚨In many cases, using rugplot alone may not be very understandable for the people you are presenting to. So, combining the rug plot with a histogram (or kernel density estimate) provides a clearer picture of the data distribution:**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Rug Plot and Scatter Plot with Seaborn:</strong></p>
#
#
# **The following code creates a ``scatter plot`` to visualize the ``relationship between total_bill and tip amounts`` from the tips dataset, and a ``rug plot`` is added to show the ``distribution of the total_bill along the x-axis``.**

# %%
# Create the Scatter plot
sns.scatterplot(data=tips, x="total_bill", y="tip")

# Add the rug plot
sns.rugplot(data=tips, x="total_bill", y="tip");

# %% [markdown]
# - So based on this histogram, we reliaze that the majority of the tips given are roughly between \\$1.50 and just under \\$4.
#
# - We see the occasional tip at \\$9 and \\$10. But the majority are in the \\$1.50-$4 range.
#
# - So we can see how rugplots gives vertical lines horizontally across to plot data.
#
# - Areas where there is great occurrence has great density because the lines are stacked up on each other, giving a thicker appearance.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Rug Plot and KDE Plot with Seaborn:</strong></p>
#
# **The following code creates a ``Kernel Density Estimate (KDE)`` plot to visualize the ``distribution of total_bill amounts`` from the tips dataset, and a ``rug plot`` is added to show the ``individual data points along the x-axis``.**

# %%
# Create the KDE plot
sns.kdeplot(data=tips, x="total_bill")

# Add the rug plot
sns.rugplot(x='total_bill', data=tips);

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Rug Plot and Distribution Plot with Seaborn:</strong></p>
#
#
# **The following code creates a ``distribution plot`` (using displot) to visualize the ``distribution of total_bill amounts`` from the tips dataset, including a ``Kernel Density Estimate (KDE)`` overlay, and then adds a ``rug plot`` to indicate ``individual data points along the x-axis``.**

# %%
# Create the distribution (dis) plot
sns.displot(data=tips, x="total_bill", kde=True, color="g")

# Add the rug plot
sns.rugplot(x='total_bill', data=tips);

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Modifying the Height of Rug Plot with Seaborn:</strong></p>
#
# **The following code creates a ``rug plot`` using Seaborn to visualize the ``distribution of total_bill amounts`` from the tips dataset.**

# %%
# Create the rug plot

sns.rugplot(x='total_bill', data=tips, height=0.5);

# %% [markdown]
# - **``height=0.5``**: This parameter sets the height of the rug marks. A value of 0.5 means the marks will be half the height of the default.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">DISPLOT & HISTPLOT</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The rugplot itself is not very informative for larger data sets distribution around the mean since so many ticks makes it hard to distinguish one tick from another. Instead we should count the number of tick marks per some segment of the x axis, then construct a histogram from this.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>🤔💭 What is ``Distplot`` in Seaborn❓</strong></p>
#
#
# A Distplot or distribution plot, depicts the variation in the data distribution. Seaborn Distplot represents the overall distribution of continuous data variables. The Seaborn module along with the Matplotlib module is used to depict the distplot with different variations in it.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>⚠️ Warning ⚠️</strong></p>
#
#
# This function (Distplot) is **deprecated** and will be removed in a future version. Please adapt your code to use one of two new functions:
#
# - **``displot()``,** a figure-level function with a similar flexibility over the kind of plot to draw
#
# - **``histplot()``,** an axes-level function for plotting histograms, including with kernel density smoothing
#
# Plot univariate or bivariate histograms to show distributions of datasets.
#
# A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within disrete bins.
#
# This function can normalize the statistic computed within each bin to estimate frequency, density or probability mass, and it can add a smooth curve obtained using a kernel density estimate, similar to kdeplot().
#
# The displot is a plot type that can show you the distribution of a single feature. It is a histogram with the option of adding a "KDE" plot (Kernel Density Estimation) on top of the histogram. Let's explore its use cases and syntax.
#
# - 🧐 **[seaborn.displot](https://seaborn.pydata.org/generated/seaborn.displot.html#seaborn.displot)**,<br>
# - 🧐 **[How to Make Histograms with Density Plots with Seaborn histplot?](https://www.geeksforgeeks.org/how-to-make-histograms-with-density-plots-with-seaborn-histplot/)**<br>
# - 🧐 **[seaborn.histplot](https://seaborn.pydata.org/generated/seaborn.histplot.html)**<br>
# - 🧐 **[Histograms and Density Plots in Python](https://towardsdatascience.com/histograms-and-density-plots-in-python-f6bda88f5ac0)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">DISPLOT</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>🤔💭 What is the displot vs distplot❓</strong></p>
#
# A displot or distribution plot is a fundamental tool in data visualization that helps in understanding and analyzing the distribution of data points in a dataset. It can take various forms, including histograms and KDE plots, and is widely used in data analysis across different programming environments and libraries.
#
# - **``Purpose``**: A distribution plot is used to depict the frequency or probability distribution of a dataset. It helps in understanding how data points are spread across different values.
# - **``Common Types``**:
#   - **``Histograms``**: Show the frequency of data points within specified ranges (bins).
#   - **``Kernel Density Estimates (KDE)``**: Provide a smoothed curve that represents the probability density function of the variable.
#   - **``Box Plots``**: Highlight the median, quartiles, and potential outliers in the data.
#
# **The following code snippet is used to ``embed a YouTube video within a Jupyter Notebook`` using the IPython.display module.**

# %%
from IPython.display import YouTubeVideo

# Embed the YouTube video
YouTubeVideo('4DA_dgc521o', width=800, height=500)

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Docstring of displot()</strong></p>

# %% [raw]
# sns.displot(
#             data=None,
#             *,
#             x=None,
#             y=None,
#             hue=None,
#             row=None,
#             col=None,
#             weights=None,
#             kind='hist',
#             rug=False,
#             rug_kws=None,
#             log_scale=None,
#             legend=True,
#             palette=None,
#             hue_order=None,
#             hue_norm=None,
#             color=None,
#             col_wrap=None,
#             row_order=None,
#             col_order=None,
#             height=5,
#             aspect=1,
#             facet_kws=None,
#             **kwargs,
#             )
# Docstring:
# Figure-level interface for drawing distribution plots onto a FacetGrid.
#
# This function provides access to several approaches for visualizing the univariate or bivariate distribution of data, including subsets of data defined by semantic mapping and faceting across multiple subplots. The ``kind`` parameter selects the approach to use:
#
# - :func:`histplot` (with ``kind="hist"``; the default)
# - :func:`kdeplot` (with ``kind="kde"``)
# - :func:`ecdfplot` (with ``kind="ecdf"``; univariate-only)
#
# Additionally, a :func:`rugplot` can be added to any kind of plot to show individual observations.
#
# Extra keyword arguments are passed to the underlying function, so you should refer to the documentation for each to understand the complete set of options for making plots with this interface.
#
# See the :doc:`distribution plots tutorial <../tutorial/distributions>` for a more in-depth discussion of the relative strengths and weaknesses of each approach. The distinction between figure-level and axes-level functions is explained further in the :doc:`user guide <../tutorial/function_overview>`.
#
# Parameters
# ----------
# data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence Input data structure. Either a long-form
#     collection of vectors that can be assigned to named variables or a wide-form dataset that will be internally reshaped.
# x, y : vectors or keys in ``data``
#     Variables that specify positions on the x and y axes.
# hue : vector or key in ``data``
#     Semantic variable that is mapped to determine the color of plot elements.
# row, col : vectors or keys in ``data``
#     Variables that define subsets to plot on different facets.
# kind : {"hist", "kde", "ecdf"}
#     Approach for visualizing the data. Selects the underlying plotting function and determines the additional set of valid parameters.
# rug : bool
#     If True, show each observation with marginal ticks (as in :func:`rugplot`).
# rug_kws : dict
#     Parameters to control the appearance of the rug plot.
# log_scale : bool or number, or pair of bools or numbers
#     Set axis scale(s) to log. A single value sets the data axis for univariate distributions and both axes for bivariate
#     distributions. A pair of values sets each axis independently. Numeric values are interpreted as the desired base (default
#     10). If `False`, defer to the existing Axes scale.
# legend : bool
#     If False, suppress the legend for semantic variables.
# palette : string, list, dict, or :class:`matplotlib.colors.Colormap`
#     Method for choosing the colors to use when mapping the ``hue`` semantic.
#     String values are passed to :func:`color_palette`. List or dict values imply categorical mapping, while a colormap object
#     implies numeric mapping.
# hue_order : vector of strings
#     Specify the order of processing and plotting for categorical levels of the
#     ``hue`` semantic.
# hue_norm : tuple or :class:`matplotlib.colors.Normalize`
#     Either a pair of values that set the normalization range in data units or an object that will map from data units into a [0, 1] interval. Usage implies numeric mapping.
# color : :mod:`matplotlib color <matplotlib.colors>`
#     Single color specification for when hue mapping is not used. Otherwise, the plot will try to hook into the matplotlib property cycle.
# col_wrap : int
#     "Wrap" the column variable at this width, so that the column facets span multiple rows. Incompatible with a ``row`` facet.
# {row,col}_order : vector of strings
#     Specify the order in which levels of the ``row`` and/or ``col`` variables appear in the grid of subplots.
# height : scalar
#     Height (in inches) of each facet. See also: ``aspect``.
# aspect : scalar
#     Aspect ratio of each facet, so that ``aspect * height`` gives the width of each facet in inches.
# facet_kws : dict
#     Additional parameters passed to :class:`FacetGrid`.
#
# kwargs
#     Other keyword arguments are documented with the relevant axes-level function:
#
#     - :func:`histplot` (with ``kind="hist"``)
#     - :func:`kdeplot` (with ``kind="kde"``)
#     - :func:`ecdfplot` (with ``kind="ecdf"``)
#
# Returns
# -------
# :class:`FacetGrid`
#     An object managing one or more subplots that correspond to conditional data subsets with convenient methods for
#     batch-setting of axes attributes.
#
# See Also
# --------
# histplot : Plot a histogram of binned counts with optional normalization or smoothing.
# kdeplot : Plot univariate or bivariate distributions using kernel density estimation.
# rugplot : Plot a tick at each observation value along the x and/or y axes.
# ecdfplot : Plot empirical cumulative distribution functions.
# jointplot : Draw a bivariate plot with univariate marginal distributions.

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Distribution Plot with Seaborn:</strong></p>
#
#
# **The following line of code belove creates a ``distribution plot`` using Seaborn, which visualizes the ``distribution of the "total_bill"`` variable from the tips dataset.**

# %%
# Create a distribution plot for total bill

sns.displot(x='total_bill', data=tips);

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Distribution Plot with Seaborn:</strong></p>
#
# **The following line of code creates a ``distribution plot (or histogram)`` for the ``total_bill amounts`` from the tips dataset using Seaborn's displot function.**

# %%
# Create a distribution plot for total bill

sns.displot(tips['total_bill']);

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Distribution Plot with kde parameter:</strong></p>
#
#
# **The displot function is ``generally used to combine`` both a ``histogram`` and a ``kernel density estimate (KDE)`` by default.**

# %%
# Create a distribution plot for total bill with KDE

sns.displot(x='total_bill', data=tips, kde=True);

# %% [markdown]
# - **``kde=True``**: This parameter indicates that a kernel density estimate should be included in the plot, providing a smooth estimate of the distribution.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Distribution Plot with kde and rug parameters:</strong></p>
#
#
# **The following line of code creates a ``distribution plot`` that includes a histogram, a ``Kernel Density Estimate (KDE)``, and a ``rug plot`` for the ``total_bill amounts`` in the tips dataset.**

# %%
sns.displot(x='total_bill', data=tips, kde=True, rug=True, color="salmon");

# %% [markdown]
# - **``kde=True``**: This enables the overlay of a Kernel Density Estimate on the histogram, providing a smooth representation of the data distribution.
# - **``rug=True``**: This adds a rug plot at the bottom of the plot, indicating individual data points along the x-axis.
# - **``color="salmon"``**: This sets the color of the histogram bars and the KDE line to a salmon hue.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">HISTPLOT</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>🤔💭 How to make a Seaborn histogram plot❓</strong></p>
#
#
# **The following code snippet is used to ``embed a YouTube video within a Jupyter Notebook`` using the IPython.display module.**

# %%
from IPython.display import YouTubeVideo

# Embed the YouTube video
YouTubeVideo('Bjz00ygERxY', width=800, height=500)

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Docstring of histplot()</strong></p>

# %% [raw]
# sns.histplot(
#             data=None,
#             *,
#             x=None,
#             y=None,
#             hue=None,
#             weights=None,
#             stat='count',
#             bins='auto',
#             binwidth=None,
#             binrange=None,
#             discrete=None,
#             cumulative=False,
#             common_bins=True,
#             common_norm=True,
#             multiple='layer',
#             element='bars',
#             fill=True,
#             shrink=1,
#             kde=False,
#             kde_kws=None,
#             line_kws=None,
#             thresh=0,
#             pthresh=None,
#             pmax=None,
#             cbar=False,
#             cbar_ax=None,
#             cbar_kws=None,
#             palette=None,
#             hue_order=None,
#             hue_norm=None,
#             color=None,
#             log_scale=None,
#             legend=True,
#             ax=None,
#             **kwargs,
#             )
# Docstring:
# Plot univariate or bivariate histograms to show distributions of datasets.
#
# A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within disrete bins.
#
# This function can normalize the statistic computed within each bin to estimate frequency, density or probability mass, and it can add a smooth curve obtained using a kernel density estimate, similar to :func:`kdeplot`.
#
# More information is provided in the :ref:`user guide <tutorial_hist>`.
#
# Parameters
# ----------
# data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence Input data structure. Either a long-form
#     collection of vectors that can be assigned to named variables or a wide-form dataset that will be internally reshaped.
# x, y : vectors or keys in ``data``
#     Variables that specify positions on the x and y axes.
# hue : vector or key in ``data``
#     Semantic variable that is mapped to determine the color of plot elements.
# weights : vector or key in ``data``
#     If provided, weight the contribution of the corresponding data points towards the count in each bin by these factors.
# stat : str
#     Aggregate statistic to compute in each bin.
#
#     - `count`: show the number of observations in each bin
#     - `frequency`: show the number of observations divided by the bin width
#     - `probability`: or `proportion`: normalize such that bar heights sum to 1
#     - `percent`: normalize such that bar heights sum to 100
#     - `density`: normalize such that the total area of the histogram equals 1
# bins : str, number, vector, or a pair of such values
#     Generic bin parameter that can be the name of a reference rule, the number of bins, or the breaks of the bins.
#     Passed to :func:`numpy.histogram_bin_edges`.
# binwidth : number or pair of numbers
#     Width of each bin, overrides ``bins`` but can be used with
#     ``binrange``.
# binrange : pair of numbers or a pair of pairs
#     Lowest and highest value for bin edges; can be used either with ``bins`` or ``binwidth``. Defaults to data extremes.
# discrete : bool
#     If True, default to ``binwidth=1`` and draw the bars so that they are centered on their corresponding data points. This
#     avoids "gaps" that may otherwise appear when using discrete (integer) data.
# cumulative : bool
#     If True, plot the cumulative counts as bins increase.
# common_bins : bool
#     If True, use the same bins when semantic variables produce multiple plots. If using a reference rule to determine the bins,
#     it will be computed with the full dataset.
# common_norm : bool
#     If True and using a normalized statistic, the normalization will apply over the full dataset. Otherwise, normalize each
#     histogram independently.
# multiple : {"layer", "dodge", "stack", "fill"}
#     Approach to resolving multiple elements when semantic mapping creates subsets.
#     Only relevant with univariate data.
# element : {"bars", "step", "poly"}
#     Visual representation of the histogram statistic.
#     Only relevant with univariate data.
# fill : bool
#     If True, fill in the space under the histogram.
#     Only relevant with univariate data.
# shrink : number
#     Scale the width of each bar relative to the binwidth by this factor.
#     Only relevant with univariate data.
# kde : bool
#     If True, compute a kernel density estimate to smooth the distribution and show on the plot as (one or more) line(s).
#     Only relevant with univariate data.
# kde_kws : dict
#     Parameters that control the KDE computation, as in :func:`kdeplot`.
# line_kws : dict
#     Parameters that control the KDE visualization, passed to :meth:`matplotlib.axes.Axes.plot`.
# thresh : number or None
#     Cells with a statistic less than or equal to this value will be transparent.
#     Only relevant with bivariate data.
# pthresh : number or None
#     Like ``thresh``, but a value in [0, 1] such that cells with aggregate counts (or other statistics, when used) up to this proportion of the total will be
#     transparent.
# pmax : number or None
#     A value in [0, 1] that sets that saturation point for the colormap at a value such that cells below is constistute this proportion of the total count (or
#     other statistic, when used).
# cbar : bool
#     If True, add a colorbar to annotate the color mapping in a bivariate plot.
#     Note: Does not currently support plots with a ``hue`` variable well.
# cbar_ax : :class:`matplotlib.axes.Axes`
#     Pre-existing axes for the colorbar.
# cbar_kws : dict
#     Additional parameters passed to :meth:`matplotlib.figure.Figure.colorbar`.
# palette : string, list, dict, or :class:`matplotlib.colors.Colormap`
#     Method for choosing the colors to use when mapping the ``hue`` semantic.
#     String values are passed to :func:`color_palette`. List or dict values
#     imply categorical mapping, while a colormap object implies numeric mapping.
# hue_order : vector of strings
#     Specify the order of processing and plotting for categorical levels of the
#     ``hue`` semantic.
# hue_norm : tuple or :class:`matplotlib.colors.Normalize`
#     Either a pair of values that set the normalization range in data units or an object that will map from data units into a
#     [0, 1] interval. Usage
#     implies numeric mapping.
# color : :mod:`matplotlib color <matplotlib.colors>`
#     Single color specification for when hue mapping is not used. Otherwise, the plot will try to hook into the matplotlib
#     property cycle.
# log_scale : bool or number, or pair of bools or numbers
#     Set axis scale(s) to log. A single value sets the data axis for univariate distributions and both axes for bivariate
#     distributions. A pair of values sets each axis independently. Numeric values are interpreted as the desired
#     base (default 10). If `False`, defer to the existing Axes scale.
# legend : bool
#     If False, suppress the legend for semantic variables.
# ax : :class:`matplotlib.axes.Axes`
#     Pre-existing axes for the plot. Otherwise, call :func:`matplotlib.pyplot.gca` internally.
# kwargs
#     Other keyword arguments are passed to one of the following matplotlib
#     functions:
#
#     - :meth:`matplotlib.axes.Axes.bar` (univariate, element="bars")
#     - :meth:`matplotlib.axes.Axes.fill_between` (univariate, other element, fill=True)
#     - :meth:`matplotlib.axes.Axes.plot` (univariate, other element, fill=False)
#     - :meth:`matplotlib.axes.Axes.pcolormesh` (bivariate)
#
# Returns
# -------
# :class:`matplotlib.axes.Axes`
#     The matplotlib axes containing the plot.
#
# See Also
# --------
# displot : Figure-level interface to distribution plot functions.
# kdeplot : Plot univariate or bivariate distributions using kernel density estimation.
# rugplot : Plot a tick at each observation value along the x and/or y axes.
# ecdfplot : Plot empirical cumulative distribution functions.
# jointplot : Draw a bivariate plot with univariate marginal distributions.

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Histogram with Seaborn:</strong></p>
#
#
# **The line of code below ``creates a histogram`` using Seaborn to visualize the `distribution of the "total_bill"`` variable from the tips dataset. The histplot function provides a straightforward way to visualize the ``frequency of data points`` across ``specified bins``.**

# %%
# Create a histogram for total bill

sns.histplot(data=tips, x='total_bill');

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Histogram with kde parameter:</strong></p>
#
# **The following line of code creates a ``histogram`` to visualize the ``distribution of total_bill amounts`` from the tips dataset, with an overlay of a ``Kernel Density Estimate (KDE)``.**

# %%
# Create a histogram for total bill with KDE

sns.histplot(tips['total_bill'], kde=True);

# %% [markdown]
# - **``kde=True``**: This parameter indicates that a kernel density estimate should be included in the plot, providing a smooth estimate of the distribution.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Histogram with kde parameter:</strong></p>
#
# **The following line of code creates a ``histogram`` for the ``total_bill amounts`` in the tips dataset, with an overlay of a ``Kernel Density Estimate (KDE)``.**

# %%
sns.histplot(data=tips, x='total_bill', kde=True);

# %% [markdown]
# **Summary:**
# - **``Histogram``**: The **``sns.histplot()``** function visualizes the **``distribution of the "total_bill"``** variable by showing the **``frequency of total bill amounts``** across **``specified bins``**.
# - **``KDE Overlay``**: By setting **``kde=True``**, the plot includes a kernel density estimate, which gives a **``smooth representation of the data’s distribution``**, helping to visualize where the data points are concentrated.
# - **``Data Insights``**: This visualization is useful for understanding the distribution of total bills, highlighting the overall shape, spread, and peaks of the data.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">The Number of Bins in Histogram</p>
#
# <a id="8.1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The choice of bins for computing and plotting a histogram can exert substantial influence on the insights that one is able to draw from the visualization. If the bins are too large, they may erase important features. On the other hand, bins that are too small may be dominated by random variability, obscuring the shape of the true underlying distribution. The default bin size is determined using a reference rule that depends on the sample size and variance. This works well in many cases, (i.e., with “well-behaved” data) but it fails in others. It is always a good to try different bin sizes to be sure that you are not missing something important. This function allows you to specify bins in several different ways, such as by setting the total number of bins to use, the width of each bin, or the specific locations where the bins should break.
#
# **[SOURCE: Official Seaborn histplot() Web Page](https://seaborn.pydata.org/generated/seaborn.histplot.html)**
#
# - ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>Approach 1:</strong></p>
#
#   - **[Here's One of the Way How to Calculate the Number of Bins and the Bin Width for a Histogram](https://www.qimacros.com/histogram-excel/how-to-determine-histogram-bin-interval/)**
#     - Count the number of data points.
#     - Calculate the number of bins by taking the square root of the number of data points and round up.
#     - Calculate the bin width by dividing the specification tolerance or range (USL-LSL or Max-Min value) by the # of bins.
#
# **Bin Width = (Max-Min)/sqrt(n)**
#
# - ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>Approach 2:</strong></p>
#
#   - **[Calculating optimal number of bins in a histogram](https://stats.stackexchange.com/questions/798/calculating-optimal-number-of-bins-in-a-histogram)**
#
#
# - ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>Approach 3 (Intuative):</strong></p>
#
# <img src=https://i.ibb.co/b173z4S/guideline-for-bins-number.png width="700" height="200">
#
# **[How to decide on the number of bins of a Histogram?](https://medium.datadriveninvestor.com/how-to-decide-on-the-number-of-bins-of-a-histogram-3c36dc5b1cd8)**
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">👉 In Seaborn, when we set the bins parameter to 'auto' which is default, it automatically determines the number of bins based on the data, using algorithms that can provide a good balance between detail and clarity. In contrast, specifying bins=10 in Matplotlib creates a fixed number of bins, regardless of the data distribution.</p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Histogram with automatic bin sizing:</strong></p>
#
#
# **The following line of code creates a ``histogram`` for the ``total_bill amounts`` in the tips dataset using Seaborn, with ``automatic bin sizing``.**

# %%
# While the number of bins=10 in matplotlib, bins='auto' in seaborn

# Create a Seaborn histogram with auto bins
sns.histplot(data=tips, x='total_bill');

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Modifying bin number in Histogram:</strong></p>
#
#
# **Using different settings allows us to explore how the choice of bins affects the visualization of the data distribution:**

# %%
# Create a histogram for total bill with 20 bins

sns.histplot(data=tips, x='total_bill', bins=20);

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Modifying bin number in Histogram intuitively:</strong></p>
#
# **The following line of code creates a ``histogram`` for the ``total_bill amounts`` in the tips dataset, ``specifying the number of bins`` to use.**

# %%
# Create a histogram for total bill with 50 bins

sns.histplot(data=tips, x='total_bill', bins=50);

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Modifying bin number in Histogram based on Sturge’s rule:</strong></p>
#
#
# **The code below uses Sturge’s rule to calculate the optimal number of bins for a histogram, which is particularly useful for visualizing the distribution of the "total_bill" variable in the tips dataset. Here’s a breakdown of the code, along with an example implementation:**

# %%
# Method 1: Sturge’s rule

# Calculate the optimal number of bins
bin_count = int(np.ceil(np.log2(len(tips.total_bill))) + 1)  

# Create a new figure with the specified size
fig = plt.figure(figsize=(7, 7))

# Create the histogram
sns.histplot(x=tips.total_bill, bins=bin_count)

# Set the title
plt.title(f'bins = {bin_count}');

# %% [markdown]
# - **``Sturge’s Rule``**: This method helps determine a reasonable number of bins for a histogram based on the size of the dataset, which can improve the clarity of the visualization.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Modifying bin number in Histogram based on Freedman-Diaconis rule:</strong></p>
#
# **The following code implements the ``Freedman-Diaconis rule`` to determine the ``optimal number of bins`` for a histogram of the total_bill amounts in the tips dataset.**

# %%
# Method 2: Freedman-Diaconis rule

q1 = tips.total_bill.quantile(0.25)  # Calculates the the 25th percentile (Q1)
q3 = tips.total_bill.quantile(0.75)  # Calculates the 75th percentile (Q3)
iqr = q3 - q1  # Calculates the difference between the 75th percentile (Q3) and the 25th percentile (Q1)
bin_width = (2 * iqr) / (len(tips.total_bill) ** (1 / 3))  # The formula for bin width
bin_count = int(np.ceil((tips.total_bill.max() - tips.total_bill.min()) / bin_width))  #  The calculated number of bins

# Create a new figure with the specified size
fig = plt.figure(figsize=(7, 7))

# Create the histogram
sns.histplot(x=tips.total_bill, bins=bin_count)

# Set the title
plt.title(f'bins = {bin_count}');

# %% [markdown]
# - **``Freedman-Diaconis Rule``**: This method provides a robust way to determine the number of bins by focusing on the IQR, making it effective for datasets with outliers or skewed distributions.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">👉 Seaborn used Freedman-Diaconis rule in version 0.9 to calculate bin width if bins parameter is NOT specified in the function seaborn, BUT it changed in version 0.10. In the latest version it uses ``reference rule`` that depends on the ``sample size and variance``. </p>
#
# **[Ensuring Consistent Bin Intervals for Multiple Seaborn Histograms with the Freedman-Diaconis Rule](https://stackoverflow.com/questions/66446681/ensuring-consistent-bin-intervals-for-multiple-seaborn-histograms-with-the-freed)**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:125%; text-align:left;"><strong>👉 From Seaborn Documentation:</strong></p>
#
#
# The **``choice of bins``** for computing and plotting a histogram can exert **``substantial influence on the insights``** that one is able to draw from the visualization. If the bins are **``too large``**, they may **``erase important features``**. On the other hand, bins that are **``too small``** may be **``dominated by random variability``**, **``obscuring the shape of the true underlying distribution``**. The default bin size is determined using a **``reference rule``** that depends on the **``sample size and variance``**. This works well in many cases, (i.e., with "well-behaved" data) but it fails in others. It is always a good to try different bin sizes to be sure that you are not missing something important. This function allows you to specify bins in several different ways, such as by setting the total number of bins to use, the width of each bin, or the specific locations where the bins should break.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Adding in a Grid & Styles</p>
#
# <a id="8.2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - **``sns.set()``** We can also customize seaborn theme or use one of six variations of the default theme. Which are called deep, muted, pastel, bright, dark, and colorblind.
#
# - We can reset to a different default style: one of {**``darkgrid``**, **``whitegrid``**, **``dark``**, **``white``**, **``ticks``**}.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">👉 In a later notebook and lecture we will cover custom styling in a lot more detail.</p>
#
#
#
# - 🧐 **[Seaborn is actually quite good for data visualization](https://towardsdatascience.com/matplotlib-seaborn-basics-2bd7b66dbee2)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Modifying Background Style and Creating a Histogram with customized bin number:</strong></p>
#
# **The following code ``sets the Seaborn style to "darkgrid"`` and then creates a ``histogram`` for the ``total_bill amounts`` in the tips dataset with ``20 bins``.**

# %%
# Set the Seaborn style
sns.set(style='darkgrid')  # This function may be removed in the future.

# Create a histogram for total bill with 20 bins
sns.histplot(data=tips, x='total_bill', bins=20);

# %% [markdown]
# - **``sns.set(style='darkgrid')``**: This function sets the aesthetic style of the plots to "darkgrid", which adds a dark background with grid lines. This style can enhance the visibility of the plot elements.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Modifying Background Style and Creating a Histogram with customized bin number:</strong></p>
#
# **The following code ``sets the Seaborn style to "whitegrid"`` and creates a ``histogram`` for the ``total_bill amounts`` in the tips dataset using ``20 bins``.**

# %%
# Set the Seaborn style
sns.set(style='whitegrid')

# Create a histogram for total bill with 20 bins
sns.histplot(data=tips, x='total_bill', bins=20);

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Adding in Keywords from Matplotlib</p>
#
# <a id="8.3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Seaborn plots can **``accept keyword arguments directly from the matplotlib``** code that seaborn uses. Keep in mind, **``NOT every seaborn plot can accept all matplotlib arguments``**, but the main styling parameters we've discussed are available.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Docstring of displot()</strong></p>

# %% [raw]
# sns.displot(
#             data=None,
#             *,
#             x=None,
#             y=None,
#             hue=None,
#             row=None,
#             col=None,
#             weights=None,
#             kind='hist',
#             rug=False,
#             rug_kws=None,
#             log_scale=None,
#             legend=True,
#             palette=None,
#             hue_order=None,
#             hue_norm=None,
#             color=None,
#             col_wrap=None,
#             row_order=None,
#             col_order=None,
#             height=5,
#             aspect=1,
#             facet_kws=None,
#             **kwargs,
#             )

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Distribution Plot with Parameters in Matplotlib:</strong></p>
#
# **The following code creates a ``distribution plot (histogram)`` for the ``total_bill amounts`` in the tips dataset, with specific customization options.**

# %%
# Create a distribution plot for total bill

sns.displot(data=tips,          # Specifies the dataset to use
            x='total_bill',     # Indicates the variable to be plotted on the x-axis
            bins=20,            # SEABORN-Sets the number of bins to 20
            kde=False,          # SEABORN-Indicates that a kernel density estimate should not be included in the plot
            color='red',        # SEABORN-Sets the fill color of the histogram bars to red
            edgecolor='black',  # MATPLOTLIB-Sets the line width of the edges to 4
            lw=4,               # MATPLOTLIB-Sets the line width of the edges to 4
            ls='--');           # MATPLOTLIB-Sets the line style of the edges to dashed

# %% [markdown]
# **``Seaborn Parameters:``**
#    - **``bins``**: Sets the number of bins for the histogram.
#    - **``kde``**: Controls whether to include a kernel density estimate.
# color: Sets the fill color of the bars.
#
# **``Matplotlib Parameters:``**
#    - **``edgecolor``**: Specifies the color of the edges of the bars.
#    - **``lw (line width)``**: Sets the line width of the edges.
#    - **``ls (line style)``**: Defines the line style of the edges.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">THE KERNEL DENSITY ESTIMATION (KDE) PLOT</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions. The approach is explained further in the [user guide](https://seaborn.pydata.org/tutorial/distributions.html#tutorial-kde).
#
# The KDE plot maps an estimate of a probability *density* function of a random variable. Kernel density estimation is a fundamental data smoothing problem where inferences about the population are made, based on a finite data sample.
#
# - 🧐 **[seaborn.kdeplot](https://seaborn.pydata.org/generated/seaborn.kdeplot.html#:~:text=A%20kernel%20density%20estimate%20(KDE,further%20in%20the%20user%20guide.)**
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>🤔💭 How does a Kernel Density Estimation work❓</strong></p>
#
#
# - The Kernel Density Estimation works by plotting out the data and beginning to create a curve of the distribution. The **``curve``** is calculated by **``weighing the distance of all the points in each specific location along the distribution``**. If there are **``more points grouped locally``**, the **``estimation is higher as the probability of seeing a point at that location increases``**. The **``kernel function``** is the specific mechanism used to **``weigh the points``** across the data set. The **``bandwidth of the kernel changes its shape``**. A lower bandwidth limits the scope of the function and leads to the estimate curve looking rough and jagged. By tweaking the parameters of the kernel function (bandwidth and amplitude), one changes the size and shape of the estimate.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>🤔💭 Kernel Density Estimation and Machine Learning:</strong></p>
#
#
# - The Kernel Density Estimation technique can be incorporated into [machine learning](https://deepai.org/machine-learning-glossary-and-terms/machine-learning) applications. For example, as the estimation function has parameters to define the scope of the kernel, a [neural network](https://deepai.org/machine-learning-glossary-and-terms/neural-network) can begin to train itself to correct its estimations and produce more accurate results. As the estimation process repeats itself, the bandwidth and amplitude estimations are continuously updated to increase the accuracy of the estimated probability density curve.
#
# - 🧐 **[What is a Kernel Density Estimation?](https://deepai.org/machine-learning-glossary-and-terms/kernel-density-estimation)**
#
# ![bandwith.png](https://i.ibb.co/WcKMGLV/bandwith-PNG.png)
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>🤔💭 What is kernel density estimation? And how to build a KDE plot in Python❓</strong></p>
#
#
#
# **The following code snippet is used to ``embed a YouTube video within a Jupyter Notebook`` using the IPython.display module.**

# %%
from IPython.display import YouTubeVideo

# Embed the YouTube video
YouTubeVideo('DCgPRaIDYXA', width=800, height=500)

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Docstring of kdeplot()</strong></p>

# %% [raw]
# sns.kdeplot(
#             x=None,
#             *,
#             y=None,
#             shade=None,
#             vertical=False,
#             kernel=None,
#             bw=None,
#             gridsize=200,
#             cut=3,
#             clip=None,
#             legend=True,
#             cumulative=False,
#             shade_lowest=None,
#             cbar=False,
#             cbar_ax=None,
#             cbar_kws=None,
#             ax=None,
#             weights=None,
#             hue=None,
#             palette=None,
#             hue_order=None,
#             hue_norm=None,
#             multiple='layer',
#             common_norm=True,
#             common_grid=False,
#             levels=10,
#             thresh=0.05,
#             bw_method='scott',
#             bw_adjust=1,
#             log_scale=None,
#             color=None,
#             fill=None,
#             data=None,
#             data2=None,
#             warn_singular=True,
#             **kwargs,
#             )
# Docstring:
# Plot univariate or bivariate distributions using kernel density estimation.
#
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.
#
# The approach is explained further in the :ref:`user guide <tutorial_kde>`.
#
# Relative to a histogram, KDE can produce a plot that is less cluttered and more interpretable, especially when drawing multiple distributions. But it has the potential to introduce distortions if the underlying distribution is bounded or not smooth. Like a histogram, the quality of the representation also depends on the selection of good smoothing parameters.
#
# Parameters
# ----------
# x, y : vectors or keys in ``data``
#     Variables that specify positions on the x and y axes.
# shade : bool
#     Alias for ``fill``. Using ``fill`` is recommended.
# vertical : bool
#     Orientation parameter.
#
#     .. deprecated:: 0.11.0
#        specify orientation by assigning the ``x`` or ``y`` variables.
#
# kernel : str
#     Function that defines the kernel.
#
#     .. deprecated:: 0.11.0
#        support for non-Gaussian kernels has been removed.
#
# bw : str, number, or callable
#     Smoothing parameter.
#
#     .. deprecated:: 0.11.0
#        see ``bw_method`` and ``bw_adjust``.
#
# gridsize : int
#     Number of points on each dimension of the evaluation grid.
# cut : number, optional
#     Factor, multiplied by the smoothing bandwidth, that determines how far the evaluation grid extends past the extreme
#     datapoints. When set to 0, truncate the curve at the data limits.
# clip : pair of numbers or None, or a pair of such pairs
#     Do not evaluate the density outside of these limits.
# legend : bool
#     If False, suppress the legend for semantic variables.
# cumulative : bool, optional
#     If True, estimate a cumulative distribution function.
# shade_lowest : bool
#     If False, the area below the lowest contour will be transparent
#
#     .. deprecated:: 0.11.0
#        see ``thresh``.
#
# cbar : bool
#     If True, add a colorbar to annotate the color mapping in a bivariate plot.
#     Note: Does not currently support plots with a ``hue`` variable well.
# cbar_ax : :class:`matplotlib.axes.Axes`
#     Pre-existing axes for the colorbar.
# cbar_kws : dict
#     Additional parameters passed to :meth:`matplotlib.figure.Figure.colorbar`.
# ax : :class:`matplotlib.axes.Axes`
#     Pre-existing axes for the plot. Otherwise, call :func:`matplotlib.pyplot.gca` internally.
# weights : vector or key in ``data``
#     If provided, weight the kernel density estimation using these values.
# hue : vector or key in ``data``
#     Semantic variable that is mapped to determine the color of plot elements.
# palette : string, list, dict, or :class:`matplotlib.colors.Colormap`
#     Method for choosing the colors to use when mapping the ``hue`` semantic.
#     String values are passed to :func:`color_palette`. List or dict values imply categorical mapping, while a colormap object
#     implies numeric mapping.
# hue_order : vector of strings
#     Specify the order of processing and plotting for categorical levels of the ``hue`` semantic.
# hue_norm : tuple or :class:`matplotlib.colors.Normalize`
#     Either a pair of values that set the normalization range in data units or an object that will map from data units into a
#     [0, 1] interval. Usage
#     implies numeric mapping.
# multiple : {{"layer", "stack", "fill"}}
#     Method for drawing multiple elements when semantic mapping creates subsets.
#     Only relevant with univariate data.
# common_norm : bool
#     If True, scale each conditional density by the number of observations such that the total area under all densities sums to
#     1. Otherwise, normalize each density independently.
# common_grid : bool
#     If True, use the same evaluation grid for each kernel density estimate.
#     Only relevant with univariate data.
# levels : int or vector
#     Number of contour levels or values to draw contours at. A vector argument
#     must have increasing values in [0, 1]. Levels correspond to iso-proportions
#     of the density: e.g., 20% of the probability mass will lie below the
#     contour drawn for 0.2. Only relevant with bivariate data.
# thresh : number in [0, 1]
#     Lowest iso-proportion level at which to draw a contour line. Ignored when
#     ``levels`` is a vector. Only relevant with bivariate data.
# bw_method : string, scalar, or callable, optional
#     Method for determining the smoothing bandwidth to use; passed to
#     :class:`scipy.stats.gaussian_kde`.
# bw_adjust : number, optional
#     Factor that multiplicatively scales the value chosen using
#     ``bw_method``. Increasing will make the curve smoother. See Notes.
# log_scale : bool or number, or pair of bools or numbers
#     Set axis scale(s) to log. A single value sets the data axis for univariate distributions and both axes for bivariate
#     distributions. A pair of values sets each axis independently. Numeric values are interpreted as the desired base (default
#     10). If `False`, defer to the existing Axes scale.
# color : :mod:`matplotlib color <matplotlib.colors>`
#     Single color specification for when hue mapping is not used. Otherwise, the plot will try to hook into the matplotlib
#     property cycle.
# fill : bool or None
#     If True, fill in the area under univariate density curves or between bivariate contours. If None, the default depends on
#     ``multiple``.
# data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence
#     Input data structure. Either a long-form collection of vectors that can be assigned to named variables or a wide-form
#     dataset that will be internally reshaped.
# warn_singular : bool
#     If True, issue a warning when trying to estimate the density of data with zero variance.
# kwargs
#     Other keyword arguments are passed to one of the following matplotlib functions:
#
#     - :meth:`matplotlib.axes.Axes.plot` (univariate, ``fill=False``),
#     - :meth:`matplotlib.axes.Axes.fill_between` (univariate, ``fill=True``),
#     - :meth:`matplotlib.axes.Axes.contour` (bivariate, ``fill=False``),
#     - :meth:`matplotlib.axes.contourf` (bivariate, ``fill=True``).
#
# Returns
# -------
# :class:`matplotlib.axes.Axes`
#     The matplotlib axes containing the plot.
#
# See Also
# --------
# displot : Figure-level interface to distribution plot functions.
# histplot : Plot a histogram of binned counts with optional normalization or smoothing.
# ecdfplot : Plot empirical cumulative distribution functions.
# jointplot : Draw a bivariate plot with univariate marginal distributions.
# violinplot : Draw an enhanced boxplot using kernel density estimation.
#
# Notes
# -----
#
# The *bandwidth*, or standard deviation of the smoothing kernel, is an important parameter. Misspecification of the bandwidth can produce a distorted representation of the data. Much like the choice of bin width in a histogram, an over-smoothed curve can erase true features of a distribution, while an under-smoothed curve can create false features out of random variability. The rule-of-thumb that sets the default bandwidth works best when the true distribution is smooth, unimodal, and roughly bell-shaped. It is always a good idea to check the default behavior by using ``bw_adjust`` to increase or decrease the amount of smoothing.
#
# Because the smoothing algorithm uses a Gaussian kernel, the estimated density curve can extend to values that do not make sense for a particular dataset. For example, the curve may be drawn over negative values when smoothing data that are naturally positive. The ``cut`` and ``clip`` parameters can be used to control the extent of the curve, but datasets that have many observations close to a natural boundary may be better served by a different visualization method.
#
# Similar considerations apply when a dataset is naturally discrete or "spiky" (containing many repeated observations of the same value). Kernel density estimation will always produce a smooth curve, which would be misleading in these situations.
#
# The units on the density axis are a common source of confusion. While kernel density estimation produces a probability distribution, the height of the curve at each point gives a density, not a probability. A probability can be obtained only by integrating the density across a range. The curve is normalized so that the integral over all possible values is 1, meaning that the scale of the density axis depends on the data values.

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a KDE Plot with Seaborn:</strong></p>
#
# **The following code creates a ``Kernel Density Estimate (KDE)`` plot for the ``total_bill amounts`` in the tips dataset.**

# %%
# Create a KDE plot for total bill

sns.kdeplot(x='total_bill', data=tips);

# %% [markdown]
# - **``sns.kdeplot``**: This function generates a KDE plot, which provides a smooth estimate of the probability density function of a continuous variable.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:125%; text-align:left;"><strong>👉 From Seaborn Documentation:</strong></p>
#
# The **``bandwidth``**, or **``standard deviation of the smoothing kernel``**, is an important parameter. Misspecification of the bandwidth can produce a distorted representation of the data. Much like the choice of bin width in a histogram, an **``over-smoothed curve``** can **``erase true features of a distribution``**, while an **``under-smoothed curve``** can **``create false features out of random variability``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Cut Off KDE</p>
#
# <a id="9.1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# We could **``cut off the KDE``** if we know our data has hard limits (no one can be a negative age and no one in the population can be older than 100 for some reason)
#
# For more intiutive knowledge, dive into the discussion at stackoverflow:
#
# - 🧐 **[Limit the range of x in seaborn distplot KDE estimation](https://stackoverflow.com/questions/45911709/limit-the-range-of-x-in-seaborn-distplot-kde-estimation)**,<br>
# - 🧐 **[seaborn.kdeplot](http://man.hubwiz.com/docset/Seaborn.docset/Contents/Resources/Documents/generated/seaborn.kdeplot.html)**,<br>
# - 🧐 **[All you need to know about Seaborn](https://towardsdatascience.com/all-you-need-to-know-about-seaborn-6678a02f31ff)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a KDE Plot with Seaborn:</strong></p>
#
# **The following code creates a ``Kernel Density Estimate (KDE)`` plot for the ``total_bill amounts`` in the tips dataset.**

# %%
# Create a KDE plot for total bill

sns.kdeplot(x='total_bill', data=tips);

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a KDE Plot with clip parameter:</strong></p>
#
# **The following code creates a ``Kernel Density Estimate (KDE)`` plot for the ``total_bill amounts`` in the tips dataset, with a ``specified clipping range``.**

# %%
# Creates a new figure with the specified size
# plt.figure(figsize=(12, 8))

# Create a KDE plot for total bill with clipping
sns.kdeplot(x='total_bill', data=tips, clip=[10, 20]);

# %% [markdown]
# - **``Clipping``**: The clip parameter effectively **``zooms in on the specified range``** (between \\$10 and \\$20), which can be particularly useful for focusing on a specific segment of the data.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Bandwidth</p>
#
# <a id="9.2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# the **``KDE``** is constructed through the **``summation``** of the **``kernel``** (most commonly [Gaussian](https://en.wikipedia.org/wiki/Normal_distribution)), we can effect the **``bandwith``** of this kernel **to make the KDE more "sensitive" to the data.** Notice how with a **``smaller bandwith``**, the **``kernels do NOT stretch so wide``**, meaning we do NOT need the cut-off anymore. This is **``analagous to increasing the number of bins in a histogram``** (making the actual bins narrower).
#
# In statistics, **``Kernel Density Estimation``** is a **``non-parametric``** technique that calculates and plots the **``probability distribution (the probability density) of a continuous random variable``**. i.e., The calculation does **``NOT assume the underlying data to be following the assumptions of a normal distribution or any distribution``**.
# In simple terms, Kernel Density Estimate is like a **``smoothened counterpart of a histogram without the line of histogram intervals and their end-points``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">👉 Kernel Density Smoothing, also known as Kernel Density Estimation (KDE), replaces each sample point with a Gaussian-shaped Kernel, then obtains the resulting estimate for the density by adding up these Gaussians.</p>
#
# <img src=https://i.ibb.co/XZSdMg0/kde.png width="500" height="200">
#
# **[Image Credit](https://docs.analytica.com/index.php/Kernel_Density_Smoothing#:~:text=Kernel%20Density%20Smoothing%2C%20also%20known,by%20adding%20up%20these%20Gaussians.)**
#
# Such a **``smoothened curve``** for the probability density of a given data is obtained by drawing **``individual estimates for the data points``** and **``summing them up to produce the final contour``**.
# - The bandwidth **``'h'``** used in the estimation plays a role in the level of smoothness of the estimated curve. **The lower the 'h' - more closer to the data and more spiky the curve is. When the value of 'h' is higher the resultant curve is over smoothend.**
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>🤔💭 What is meant by Gaussian distribution❓</strong></p>
#
# - **``Normal distribution``**, also known as the **``Gaussian distribution``**, is a **``probability distribution``** that is **``symmetric about the mean``**, showing that data near the mean are more frequent in occurrence than data far from the mean. In graph form, normal distribution will appear as a **``bell curve``**.
#
# - 🧐 **[Drawing A Kernel Density Estimate(KDE) Plot Using Seaborn](https://pythontic.com/visualization/seaborn/kdeplot)**,<br>
# - 🧐 **[What is kernel density estimation? And how to build a KDE plot in Python? (Youtube)](https://www.youtube.com/watch?v=DCgPRaIDYXA)**
#
#
# <hr>
#
# - **kernel (K)** (a simple non-negative function like the normal or uniform distribution)<br>
# - **bandwidth (h)** (a real positive number that defines smoothness of the density plot)
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a KDE Plot with with Seaborn:</strong></p>
#
# **The following code creates a ``Kernel Density Estimate (KDE)`` plot for the ``total_bill amounts`` in the tips dataset.**

# %%
# Create a KDE plot for total bill

sns.kdeplot(x='total_bill', data=tips);

# %% [markdown]
# 🧐 **[Changing the bandwidth changes the shape of the kernel:](https://mathisonian.github.io/kde/)** a **``lower bandwidth``** means **``only points very close to the current position are given any weight``**, which leads to the estimate looking squiggly; a **``higher bandwidth``** means a **``shallow kernel where distant points can contribute``**.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating KDE Plot and Rug Plot with Seaborn:</strong></p>
#
# **The following code creates a ``KDE plot`` for the ``total_bill amounts`` in the tips dataset, with an ``adjusted bandwidth``, and adds a ``rug plot`` to visualize ``individual data points``.**

# %%
# Create a new figure with the specified size
plt.figure(figsize=(12, 6))

# Create a KDE plot for total bill with adjusted bandwidth
sns.kdeplot(data=tips, x="total_bill", bw_adjust=0.1);

# Add a rug plot for total bill
sns.rugplot(data=tips, x="total_bill");

# A smaller bandwidth allows the KDE to be more responsive to the data, resulting in a more detailed and potentially wiggly curve. 
# This can provide insights into the data's structure but also risks capturing noise rather than the true underlying distribution. 
# Finding the right balance with bandwidth is crucial for effective data visualization.

# %% [markdown]
# - **``bw_adjust=0.1``**: Adjusts the bandwidth of the KDE. A **``smaller value (like 0.1) results in a more sensitive estimate``**, which means the KDE will follow the data more closely, potentially leading to a more ``wiggly curve``.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>Key Concepts:</strong></p>
#
#
# 1. **``Kernel Density Estimate (KDE)``**:
#    - A KDE is a non-parametric way to estimate the probability density function of a random variable. It smooths the data by placing a kernel (a small, smooth function) at each data point and summing these contributions to create a continuous density curve.
# 2. **``Bandwidth``**:
#    - The bandwidth determines the width of the kernel used in the KDE. It controls how much the data points influence the shape of the density curve.
#    - A smaller bandwidth leads to a tighter kernel around each data point, which means that:
#      - Each data point's contribution to the density estimate is more localized.
#      - The resulting density curve can capture more of the local variations in the data, leading to a curve that closely follows the actual distribution of the data points.
# 3. **``Wiggly Curve``**:
#    - When the bandwidth is small (like in your example with bw_adjust=0.1), the KDE can show more fluctuations and peaks, resulting in a "wiggly" appearance.
#    - This wiggly nature indicates that the KDE is sensitive to the variations in the data. While it can provide a more accurate representation of the data distribution, it may also lead to overfitting, where the estimate captures noise rather than the underlying distribution.
# 4. **``Visual Example``**:
#    - Small Bandwidth: The KDE may show several peaks and troughs, reflecting every little fluctuation in the data.
#    - Large Bandwidth: The KDE becomes smoother and more generalized, potentially obscuring important features of the distribution, uch as multiple modes (peaks).
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a KDE Plot and Modifying Bandwidth:</strong></p>
#
# **The following code creates a ``Kernel Density Estimate (KDE)`` plot for the ``total_bill amounts`` in the tips dataset, with an ``adjusted bandwidth``.**

# %%
# Create a KDE plot for total bill with adjusted bandwidth

sns.kdeplot(x='total_bill', data=tips, bw_adjust=0.2);

# %% [markdown]
# - **``bw_adjust=0.2``**: This parameter adjusts the bandwidth of the KDE. A **``value less than 1``** will make the **``KDE more sensitive to fluctuations``** in the data (resulting in a more detailed curve), while a **``value greater than 1``** will **``smooth the curve more``**. In this case, **``0.2``** indicates a **``relatively narrow bandwidth``**, leading to a **``more detailed representation of the density``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a KDE Plot and Modifying Bandwidth:</strong></p>
#
# **The following code creates a ``Kernel Density Estimate (KDE)`` plot for the ``total_bill amounts`` in the tips dataset, with a ``bandwidth adjustment set to 1``.**

# %%
# Create a KDE plot for total bill with adjusted bandwidth

sns.kdeplot(x='total_bill', data=tips, bw_adjust=1);

# %% [markdown]
# - **``bw_adjust=1``**: This parameter specifies the bandwidth adjustment for the KDE. A **``value of 1``** means that the **``bandwidth is NOT altered``**; it uses the **``default bandwidth``** determined by the data. This typically results in a **``smooth curve``** that balances detail and generalization.
#
# 🧐 **[The importance of kernel density estimation bandwidth](https://aakinshin.net/posts/kde-bw/)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating Multiple KDE Plots and a Rug Plot and Modifying their Bandwidths for Comparison:</strong></p>
#
# **The following code creates a ``series of Kernel Density Estimate (KDE)`` plots for the ``total_bill amounts`` in the tips dataset, each with ``different bandwidth adjustments``. It also includes a ``rug plot`` to visualize ``individual data points``.**

# %%
# Create a new figure with the specified size
plt.figure(figsize=(12, 8))

# Create KDE plots with different bandwidth adjustments
sns.kdeplot(x='total_bill', data=tips, bw_adjust=0.1, label="Bandwidth 0.1")
sns.kdeplot(x='total_bill', data=tips, bw_adjust=0.3, label="Bandwidth 0.3")
sns.kdeplot(x='total_bill', data=tips, bw_adjust=0.5, label="Bandwidth 0.5")
sns.kdeplot(x='total_bill', data=tips, bw_adjust=0.7, label="Bandwidth 0.7")
sns.kdeplot(x='total_bill', data=tips, bw_adjust=1,   label="Bandwidth 1")

# Add a rug plot for total bill
sns.rugplot(data=tips, x="total_bill", color="orange")

# Add legend
plt.legend();

# %% [markdown]
# An important parameter is the **``bandwidth``: **``the smaller it is``**, **``the closer the curve fits to the data``**, **``the wider the better to indicate a general form``**.
#
# It seems **``Seaborn and pandas``** are using a **``different approach to estimate a "good" bandwidth``**.
# - With seaborn we could set a fixed bandwidth sns.kdeplot(..., bw=0.5) or so. Or seaborn.distplot(..., kde=True, kde_kws={'bw': 0.5}). With pandas df.plot.kde(bw_method=0.5, ...).
# - Note that the "perfect" bandwidth doesn't exist, it depends on the data, the number of samples and about what we already know about the underlying distribution.
# - The default seaborn and pandas choose is just a rule of thumb, that might be useful or not for our data. Future versions will probably use different rules of thumb.
#
# 🧐 **[Why are Pandas and Seaborn producing different KDE Plot for same data? on Stackoverflow](https://stackoverflow.com/questions/62176879/why-are-pandas-and-seaborn-producing-different-kde-plot-for-same-data)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a KDE Plot with shade and color parameters and Modifying Bandwidth:</strong></p>
#
# **The following code creates a ``Kernel Density Estimate (KDE)`` plot for the ``total_bill amounts`` in the tips dataset, with ``shading`` and a ``specified bandwidth adjustment``.**

# %%
# Create a KDE plot for total bill with shading

sns.kdeplot(x='total_bill', data=tips, bw_adjust=0.5, shade=True, color='red');

# %% [markdown]
# - **``bw_adjust=0.5``**: This parameter adjusts the bandwidth of the KDE. A value of 0.5 means the bandwidth will be narrower than the default, which can lead to a denser and slightly wiggly curve that follows the data more closely.
# - **``shade=True``**: This parameter fills the area under the KDE curve with color, enhancing the visual appeal and making it easier to perceive the density.
# - ``color='red'``: Sets the color of the KDE curve and the shaded area to red.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:CENTER; border-radius:10px 10px;">2-DIMENSIONAL KDE PLOTS</p>
#
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Just keep in your mind that we could **``compare two continuous features``** and create a 2d KDE plot showing there distributions with the same **``kdeplot()``** call.
#
# - 🧐 **[Visualizing distributions of data](https://seaborn.pydata.org/tutorial/distributions.html)**,<br>
# - 🧐 **[KDE and violin plots using seaborn](https://benalexkeen.com/kde-and-violin-plots-using-seaborn/)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# **numpy.random.normal()**
#
# - The NumPy random normal function enables you to create a NumPy array that contains normally distributed data. Normally distributed data is shaped sort of like a bell, so it's often called the “bell curve.”
#
# 🧐 **[numpy.random.normal](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html)**,<br>
# 🧐 **[A Quick Introduction to Numpy Random Normal](https://www.sharpsightlabs.com/blog/numpy-random-normal/)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Sample DataFrame:</strong></p>
#
# **Thefollowing code creates a ``DataFrame`` consisting of ``random numbers`` drawn from a ``normal distribution`` with two columns, x and y.**

# %%
# Create a DataFrame consisting of random numbers from a normal distribution with two columns 'x' and 'y'

data = pd.DataFrame(np.random.normal(0, 1, size=(100, 2)), columns=['x', 'y'])

# Display the Data
data
# Out:
#            x         y
# 0   0.302665  1.693723
# 1  -1.706086 -1.159119
# 2  -0.134841  0.390528
# 3   0.166905  0.184502
# 4   0.807706  0.072960
# ..       ...       ...
# 95 -1.549671  0.435253
# 96  1.259904 -0.447898
# 97  0.266207  0.412580
# 98  0.988773  0.513833
# 99 -0.928205  0.846904
#
# [100 rows x 2 columns]

# %% [markdown]
# **Generating Random Data:**
# - **``np.random.normal(0, 1, size=(100, 2))``**: This function generates random numbers from a normal distribution.
#    - **``0``**: The mean of the distribution.
#    - **``1``**: The standard deviation of the distribution.
#    - **``size=(100, 2)``**: Specifies that 100 rows and 2 columns of random numbers should be generated.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a KDE Plot with Seaborn:</strong></p>
#
#
# **The following code creates a ``Kernel Density Estimate (KDE)`` plot for the x variable in the DataFrame data.**

# %%
# Create a KDE plot for the 'x' variable

sns.kdeplot(data=data, x='x');

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a KDE Plot with Seaborn:</strong></p>
#
# **The following code creates a ``Kernel Density Estimate (KDE)`` plot for the y variable in the DataFrame data.**

# %%
# Create a KDE plot for the 'y' variable

sns.kdeplot(data=data, x='y');

# %% [markdown]
# **``2D KDE plots``** are a powerful tool for visualizing the **``relationships between two continuous variables``**. They are particularly beneficial in exploratory data analysis, clustering, and situations where understanding joint distributions is crucial. By providing a smooth and intuitive representation of data density, 2D KDE plots can enhance insights and inform decision-making in data-driven projects.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a 2 Dimensional KDE Plot with Seaborn:</strong></p>
#
# **The following code creates a ``2D Kernel Density Estimate (KDE)`` plot for the x and y variables in the DataFrame data.**
#
# - The resulting plot will display a 2D KDE plot, where the **``color intensity``** represents the **``density of data points in the x-y space``**. **``Areas with higher concentration of points``** will appear **``darker``** OR **``closer``**, indicating where values are more **``densely populated``**.

# %%
# Create a 2D KDE plot for the 'x' and 'y' variables

# sns.kdeplot(data=data, x='x', y='y');
sns.kdeplot(data=data, x='x', y='y', fill=True, color="salmon");

# %% [markdown]
# 2D Kernel Density Estimates (KDE) are particularly beneficial for visualizing the **``joint distribution of two continuous variables``**. Here are some key advantages and suitable use cases for 2D KDE plots:
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:130%; text-align:left;"><strong>Benefits of 2D KDE:</strong></p>
#
# - **``Visualizing Joint Distributions``**: 2D KDE plots show how two variables interact with each other, revealing **``patterns``** that **``may NOT be apparent in separate univariate analyses``**.
# - **``Identifying Correlations``**: You can easily observe the relationship between two variables, including linear and non-linear correlations, clusters, or trends.
# - **``Capturing Density``**: The KDE provides a smooth representation of the density, which can highlight areas of high and low concentration of data points, making it easier to identify where most data points are located.
# - **``Handling Multimodal Distributions``**: If the joint distribution has multiple peaks (modes), 2D KDE can effectively illustrate these features, unlike histograms which may obscure them due to binning.
# - **``Data Exploration``**: Useful in exploratory data analysis (EDA) to understand the relationships between features before applying more complex modeling techniques.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:130%; text-align:left;"><strong>Suitable Use Cases:</strong></p>
#
# - **``Scatter Plot Alternatives``**: When dealing with large datasets, scatter plots can become cluttered. A 2D KDE can provide a clearer view of the data distribution.
# - **``Clustering Analysis``**: In clustering tasks, 2D KDE can help visualize the clusters formed by different groups of data points, making it easier to assess the effectiveness of clustering algorithms.
# - **``Outlier Detection``**: By visualizing the density, you can easily identify areas of low density, which may indicate outliers or anomalies in the data.
# - **``Comparative Analysis``**: When comparing different groups or categories, 2D KDE can be used to visualize the density of each group in a unified plot, facilitating comparisons.
# - **``Feature Engineering``**: In machine learning, understanding the relationship between features can help in creating new features or transforming existing ones to improve model performance.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Scatter Plot with Seaborn:</strong></p>
#
# **The following code creates a ``scatter and KDE plot`` for the x and y variables in the DataFrame data.**

# %%
# Create a scatter and KDE plot for the 'x' and 'y' variables

sns.scatterplot(data= data, x='x', y='y')
sns.kdeplot(data=data, x='x', y='y', color="salmon");

# %% [markdown]
# - **``Scatter Plot:``**
#   - **``sns.scatterplot(data=data, x='x', y='y')``**: This function creates a scatter plot with the x values plotted along the x-axis and the y values along the y-axis. Each point represents an observation from the dataset.
# - **``KDE Plot:``**
#   - **``sns.kdeplot(data=data, x='x', y='y', color="salmon")``**: This function overlays a KDE plot on the scatter plot. The KDE plot visualizes the density of data points in the x-y space, with areas of higher density indicated by a stronger color (in this case, salmon).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">BONUS CODE FOR VISUALIZATIONS</p>
#
# <a id="11"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;">Below is the code used to create the visualizations shown in the video lecture for an explanation of a KDE plot. We will NOT cover this code in further detail, since it was only used for the creation of the slides shown in the video.</p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Sample Data:</strong></p>
#
# **The following code ``sets a seed for reproducibility`` and generates ``20 random numbers`` from a ``normal distribution``.**

# %%
# Set the seed for reproducibility
np.random.seed(101)

# Generate 20 random numbers from a normal distribution
x = np.random.normal(0, 1, size=20)

# %% [markdown]
# **Generating Random Numbers:**
# - **``np.random.normal(0, 1, size=20)``**: This function generates random numbers from a normal (Gaussian) distribution.
#    - **``0``**: This is the mean of the distribution.
#    - **``1``**: This is the standard deviation of the distribution.
#    - **``size=20``**: This specifies that you want to generate an array of 20 random numbers.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# #### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">What is dpi in Figure?</p>
#
# <a id="11.1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - **``Dots per inches (dpi)``** determines **``how many pixels the figure comprises``**.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Rug Plot with Modifying linewidth:</strong></p>
#
# **The following code creates a ``rug plot`` for the array x, displaying the ``individual data points along a single axis``.**

# %%
# Create a figure with specified size and resolution
plt.figure(figsize=(8, 4), dpi=200)

# Create a rug plot for the array x
sns.rugplot(x, color="darkblue", linewidth=4);  # linewidth sets the width of the rug lines, making them thicker

# %% [markdown]
# - **``Setting Up the Figure:``**
#   - **``plt.figure(figsize=(8, 4), dpi=200)``**: This initializes a new figure with a width of 8 inches and a height of 4 inches, and **``sets the resolution to 200 dots per inch (DPI)``**. This ensures a **``high-quality output``**.
# - **``Creating the Rug Plot:``**
#   - **``sns.rugplot(x, color="darkblue", linewidth=4)``**: This creates a rug plot where each data point in the array x is represented by a small vertical line (or tick) along the x-axis.
#   - **``color="darkblue"``**: Sets the color of the rug lines to dark blue.
#   - **``linewidth=4``**: Sets the width of the rug lines to 4 points.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:115%; text-align:left;"><strong>🎁 BONUS CODE BLOCK:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Rug Plot with their Kernels:</strong></p>
#
# **The following code creates a visual representation of ``how each individual data point contributes to the overall distribution``, using smooth Gaussian curves, and displays the original data points for reference.**

# %%
from scipy import stats

# Create a figure with specified size and resolution
plt.figure(figsize=(8, 4), dpi=200)

# Calculate bandwidth based on the standard deviation and size of x
bandwidth = x.std() * x.size ** (-0.001)

# Define the support for the kernels
support = np.linspace(-5, 5, 100)

kernels = []

plt.figure(figsize=(12 ,6))

# Loop through each data point in x
for x_i in x:
    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color="lightblue")

# Add a rug plot for the original data
sns.rugplot(x, color="darkblue", linewidth=4);

# %% [markdown]
# **Probability density function (PDF)** is a statistical expression that defines a **``probability distribution``** (the likelihood of an outcome) for a **``discrete random variable``** (e.g., a stock or ETF) as opposed to a continuous random variable.
#
# - This code uses SciPy and Matplotlib to visualize the probability density functions (PDFs) of individual data points in a dataset x using Gaussian kernels. Here’s a simple breakdown:
#
#   - **``Setup``**: The code sets up a figure with specific dimensions and high resolution for better clarity.
#   - **``Calculate Bandwidth``**: It computes a "bandwidth" value, which controls the width of the Gaussian kernels. This is influenced by the standard deviation of the data and the number of data points.
#   - **``Define Support``**: A range of values (from -5 to 5) is created to evaluate the kernel functions.
#   - **``Loop Through Data Points``**: For each data point in x:
#     - A Gaussian kernel is created centered on that point with the calculated bandwidth.
#     - The PDF of that kernel is computed over the defined range (support) and stored in a list.
#     - Each kernel is plotted as a light blue line on the figure.
#   - **``Rug Plot``**: Finally, a rug plot is added, which shows the original data points along the x-axis as small vertical lines in dark blue. This helps visualize where the actual data points are located relative to the kernels.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:115%; text-align:left;"><strong>🎁 BONUS CODE BLOCK:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Rug Plot with its Density:</strong></p>
#
# **The following code calculates the ``overall density estimate from the individual data points``, normalizes it, and visualizes it alongside the original data points, allowingusyou to see how well the estimated density fits the actual data.**
#   - A **``kernel``** is a **``mathematical function``** used in statistical analysis to **``estimate the density of data points``**. It plays a crucial role in kernel density estimation, allowing for smooth and flexible representations of data distributions.

# %%
from scipy.integrate import trapz

# Create a figure with specified size
plt.figure(figsize=(9, 4))

# Define the support for the kernels
support = np.linspace(-5, 5, 100)

# Sum the individual kernels to get the overall density estimate
density = np.sum(kernels, axis=0)

# Normalize the density using the trapezoidal rule
density /= trapz(density, support)

# Plot the estimated density
plt.plot(support, density);

# Add a rug plot for the original data
sns.rugplot(x, color="darkblue", linewidth=4);

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# - This code snippet builds upon the previous one by calculating and visualizing an **``overall density estimate for the dataset x``**. Here’s a simple breakdown of what each part does:
#
#   - **``Setup``**: It creates a new figure for plotting.
#   - **``Sum Individual Kernels``**: The code adds up all the individual Gaussian kernels (created from each data point in x) to obtain a single overall density estimate. This represents the combined effect of all the data points.
#   - **``Normalize the Density``**: It normalizes the combined density to ensure that the total area under the density curve equals 1. This is done using the trapezoidal rule (from the trapz function), which calculates the integral of the density across the defined range.
#   - **``Plot the Estimated Density``**: The normalized density is plotted as a line on the graph.
#   - **``Add a Rug Plot``**: Finally, a rug plot is added to the same figure, showing the original data points as small vertical lines in dark blue. This provides a visual reference for where the actual data points are located relative to the estimated density.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:125%; text-align:left;"><strong>📢🤔💭 What is KERNEL❓ </strong></p>
#
#
# In the context of statistics and data analysis, a kernel refers to a **``function``** used to **``estimate the probability density function (PDF) of a random variable``**. Here’s a more detailed explanation:
#
# - **``What is a Kernel?``**
#   - **``Definition``**: A kernel is a smooth, continuous function used to create a weighted estimate of the likelihood of a data point occurring at a certain value. It helps in smoothing the data points to create a continuous probability distribution.
# - **``Kernel Density Estimation (KDE):``**
#   - Kernels are often used in Kernel Density Estimation, a non-parametric way to estimate the PDF of a random variable. KDE takes a set of data points and places a kernel (like a Gaussian function) over each point.
# The resulting sum of these kernels creates a smooth curve that represents the estimated density of the data.
# - **``Common Kernel Functions:``**
#   - **``Gaussian Kernel``**: The most commonly used kernel, shaped like a bell curve. It is defined by its mean and standard deviation.
#   - **``Epanechnikov Kernel``**: A parabolic-shaped kernel that is optimal for minimizing mean integrated squared error.
#   - **``Uniform Kernel``**: A constant kernel that assigns equal weight to all points within a certain range.
# - **``Purpose of Using Kernels``**
#   - **``Smoothing``**: Kernels help to smooth out the noise in the data, providing a clearer picture of the underlying distribution.
#   - **``Flexibility``**: Unlike histogram-based methods, which can be sensitive to bin size, kernels allow for a more flexible and continuous representation of data distributions.
# Insight``**: By visualizing the density estimate using kernels, you can gain insights into the shape, central tendency, and spread of the data.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **numpy.trapz(y, x=None, dx=1.0, axis=- 1)** integrates along the given axis using the composite trapezoidal rule.
#
# - trapz computes the approximation of a definite by the trapezoid rule. trapz returns the approximation of the integral using the trapezoid rule.
#
# 🧐 **[numpy.trapz](https://numpy.org/doc/stable/reference/generated/numpy.trapz.html)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:115%; text-align:left;"><strong>🎁 BONUS CODE BLOCK:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a KDE Plot with Modifying Bandwidth by Standard Deviation:</strong></p>
#
# **The following code snippet creates a visualization of the probability density function (PDF) of a dataset x using Kernel Density Estimation (KDE).**

# %%
# Create a figure with specified size and resolution
plt.figure(figsize=(8, 4), dpi=200)

# Calculate bandwidth based on the standard deviation and size of x
bandwidth = x.std() * x.size ** (-0.001)
# Define the support for the kernels
support = np.linspace(-5, 5, 100)

kernels = []

# Define the support for the kernels
plt.figure(figsize=(12, 6))

# Loop through each data point in x to create the kernels
for x_i in x:
    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
#     plt.plot(support, kernel, color="lightblue")

# Plot the KDE using Seaborn
# sns.rugplot(x, color="darkblue", linewidth=4)
sns.kdeplot(x, linewidth=6, shade=True);

# %% [markdown]
# - **``Setup``**: It initializes a figure with specified dimensions and high resolution for clarity.
# - **``Calculate Bandwidth``**: It computes a bandwidth value, which controls **``how wide the Gaussian kernels will be``**. This is based on the **``standard deviation``** of the data and the **``number of data points``**.
# - **``Define Support``**: A range of values (from -5 to 5) is created to evaluate the kernel functions.
# - **``Kernel Creation Loop``**: For each data point in x, a Gaussian kernel is generated centered on that data point using the calculated bandwidth. The kernel's PDF is computed over the defined range, and each kernel is stored in a list.
# - **``KDE Plot with Seaborn``**: Instead of manually plotting each kernel, the code uses Seaborn’s kdeplot function to create a single smooth density estimate for the dataset. The plot is shaded and has a thicker line width for visibility.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:115%; text-align:left;"><strong>🎁 BONUS USER DEFINED FUNCTION:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a KDE Plot with its Mean and Median:</strong></p>
#
# **The following code creates a ``KDE plot`` for the ``"tip"`` variable from the tips dataset, with additional features such as ``vertical lines`` for the ``mean`` and ``median`` of the tips, as well as ``customized legends``.**

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# Create a new figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a KDE plot for 'tip' with hue based on 'size'
ax = sns.kdeplot(data=tips, x="tip", hue="size", fill=True)

# Add vertical lines for the mean and median of tips
ax.axvline(x=tips.tip.mean(), color='r', linestyle=':', lw=3)
ax.axvline(x=np.median(tips.tip), color='b', linestyle=':', lw=3);

# Create custom legend elements
legend_elements = [Line2D([0], [0], marker='s', color='blue', label='Size 1', markersize=15),
                   Line2D([0], [0], marker='s', color='lightblue', label='Size 2', markersize=15),
                   Line2D([0], [0], marker='s', color='red', label='Size 3', markersize=15),
                   Line2D([0], [0], marker='s', color='darkgreen', label='Size 4', markersize=15),
                   Line2D([0], [0], marker='s', color='lightgreen', label='Size 5', markersize=15),
                   Patch(facecolor='orange', edgecolor='r', label='Size 6')]
# Add the first legend for size types
first_legend = plt.legend(handles=legend_elements, title='Size Type', bbox_to_anchor=(0.55, 1))
plt.gca().add_artist(first_legend)

# Add a second legend for mean and median
second_legend = plt.legend(title='Tips Mean & Median', bbox_to_anchor=(0.75, 1), labels=['Tips Mean', 'Tips Median']) 
plt.gca().add_artist(second_legend);

# %% [markdown]
# 🧐 **[Composing Custom Legends](https://matplotlib.org/3.1.1/gallery/text_labels_and_annotations/custom_legends.html)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
np.median(tips.tip)
# Out:
# 2.9

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
np.mean(tips.tip)
# Out:
# 2.99827868852459

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
tips["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:115%; text-align:left;"><strong>🎁 BONUS USER DEFINED FUNCTION:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a User Defined Functions (DEFs):</strong></p>
#
# **The following function provides a ``histogram`` and a ``box plot`` to help users understand the ``frequency distribution``, ``central tendency``, and ``variability`` of the data before performing further statistical analysis.**

# %%
def show_distribution(col):
    
    '''
    
    This function will prints a Histogram and box plot which are graphical representations 
    for the frequency of numeric data values. It aims to describe the data and explore 
    the central tendency and variability before using advanced statistical analysis techniques. 
    
    '''
    # Get statistics
    from termcolor import colored

    print(colored('Statistical Calculations :', 'red', attrs=['bold']))
    print(colored('-'*26, 'red', attrs=['bold']))    
    min_val = col.min()
    max_val = col.max()
    mean_val = col.mean()
    med_val = col.median()
    mod_val = col.mode()[0]

    print(colored('Minimum:{:>7.2f}\nMean:{:>10.2f}\nMedian:{:>8.2f}\nMode:{:>10.2f}\nMaximum:{:>7.2f}\n'.format(min_val,
                                                                                             mean_val,
                                                                                             med_val,
                                                                                             mod_val,
                                                                                             max_val), 'blue', attrs=['bold']))
    
    

    # Create a figure for 2 subplots (2 rows, 1 column)
    fig, ax = plt.subplots(2, 1, figsize=(9, 7))

    # Plot the histogram   
    ax[0].hist(col, bins=30)
    ax[0].set_ylabel('Frequency', fontsize=10)

    # Add lines for the mean, median, and mode
    ax[0].axvline(x=min_val,  color='yellow',     linestyle='dashed', linewidth=2, label='Minimum')
    ax[0].axvline(x=mean_val, color='lightgreen', linestyle='dashed', linewidth=2, label='Mean')
    ax[0].axvline(x=med_val,  color='cyan',       linestyle='dashed', linewidth=2, label='Median')
    ax[0].axvline(x=mod_val,  color='purple',     linestyle='dashed', linewidth=2, label='Mode')
    ax[0].axvline(x=max_val,  color='red',        linestyle='dashed', linewidth=2, label='Maximum')
    ax[0].legend(loc=[0.7, 0.5], fontsize=8)

    # Plot the boxplot   
    medianprops = dict(linestyle='-', linewidth=3, color='m')
    boxprops=dict(linestyle='-', linewidth=1.5)
    meanprops={"marker":"d", "markerfacecolor":"red", "markeredgecolor":"black", "markersize":"10"}
    flierprops={'marker': 'o', 'markersize': 8, 'markerfacecolor': 'fuchsia'}
    
    ax[1].boxplot(col, 
                  vert=False,
                  notch=True, 
                  patch_artist=False,
                  medianprops=medianprops,
                  flierprops=flierprops,
                  showmeans=True,
                  meanprops=meanprops)
    
    ax[1].set_xlabel('value', fontsize=10)
    

    # Add a title to the Figure
    fig.suptitle('Data Distribution', fontsize=15)

# %% [markdown]
# - **``Purpose``**: The show_distribution function is designed to help users understand the **``distribution of a numeric dataset``** through visualizations and **``statistical summaries``**.
# - **``Visual Output``**: It generates a **``histogram``** and a **``box plot``**, allowing for a comprehensive view of the **``data's distribution``**, **``central tendency``**, and **``variability``**.
# - **``Statistical Insights``**: The function also provides important **``statistical information``**, which is useful for exploratory data analysis (EDA) prior to more complex analyses.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **``When we run this code, we will see:``**
#
# - Printed **``statistical values``** (minimum, mean, median, mode, maximum) in red and blue.
# - A **``histogram``** showing the frequency of total bills.
# - A **``box plot``** indicating the distribution, median, and potential outliers.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Using ``show_distribution`` function with a feature:</strong></p>
#
# - This provides a clear overview of how the total_bill amounts are distributed in the dataset.

# %%
show_distribution(tips["total_bill"])
# Out:
# Statistical Calculations :
# --------------------------
# Minimum:   3.07
# Mean:     19.79
# Median:   17.80
# Mode:     13.42
# Maximum:  50.81

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:115%; text-align:left;"><strong>🎁 BONUS CODE BLOCK:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a User Defined Functions (DEFs):</strong></p>
#
# **The following ``show_density`` function is designed to create and display a ``density plot for a numeric variable`` using a ``kernel density estimate (KDE)``.**

# %%
def show_density(col):
    
    '''
    
    This function plots a 'density plot' which is a representation of the distribution of a numeric variableand display it. 
    It uses a kernel density estimate to show the probability density function of the variable.
    
    '''    
    from matplotlib import pyplot as plt

    fig = plt.figure(figsize=(15, 5))

    # Plot density
    col.plot.density()

    # Add titles and labels
    plt.title('Data Density', fontsize=15)

    # Show the mean, median, and mode
    plt.axvline(x=col.mean(),    color='cyan',   linestyle='dashed', linewidth=2, label='Mean')
    plt.axvline(x=col.median(),  color='red',    linestyle='dashed', linewidth=2, label='Median')
    plt.axvline(x=col.mode()[0], color='yellow', linestyle='dashed', linewidth=2, label='Mode')
    plt.legend()

    # Show the figure
    plt.show()

# %% [markdown]
# - **``Purpose``**: The show_density function **``visualizes the distribution of a numeric dataset``** using a density plot and highlights important statistical measures (mean, median, and mode).
# - **``Visual Output``**: The resulting plot provides a **``smooth representation of the data's distribution``**, helping to identify patterns and central tendencies.
# - **``Statistical Insights``**: By marking the **``mean``**, **``median``**, and **``mode``**, the function helps users understand the **``central tendency of the data``** in relation to its distribution.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Using ``show_density`` function with a feature:</strong></p>
#
#
# **To use the ``show_density`` function with the ``total_bill`` column from the tips dataset helps us understand ``how the total bill amounts are distributed across the dataset``, highlighting key ``statistical measures``.**

# %%
show_density(tips["total_bill"])

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>🤔💭 Why Do We Need Data Visualization & EDA❓</strong></p>
#
# - Displaying statistical summaries
# - Gaining mor info while interpreting the data.
# - Identifying Patterns and Clusters.
# - You will mostly be expected to make decision or interpretations before diving into the model. Even if you do, you are required to capture some patterns before modelling.
# - EDA processing is critical in this case. It is critical to capture hidden and/or underlying patterns.
# - Presenting results
# - Before diving into the model, Visualization is crutial to present and percieve patterns.
# - Visualization is necessary to make the data talk to us and/or audiences. A picture is worth a thousand words.
# - It is necessary to evaluate the Model Performance.
# - EDA processing consists of most part of the data handling; on the other hand, modeling only takes 10-15% of the time.
# - The data needs to dance with the graphics/figures to reveal the underlying patterns. Or you will be got stuck with data.
# - The visualization can be obtained using Matplotlib, Seaborn and Pandas. Matplotlib is the basis of these three.
# - Seaborn: I say Statisksel says at the beginning. I use matplotlibi as a sub-structure. and a super product cikmis
# - Pandas is easy for visualization so it can firstly be prefered to visualize the data.
# - At Seaborn the great graphics can be created.
# - Matplotlib can customize the data in detail but it is complicated and cumbersome to use. On the other hand Seaborn easily uses DEFAULT values for visualization. Seaborn is also focused on statistics.
# - Using df is necessary to to make visualization at Pandas.
# - Ci: A confidence interval displays the probability (default or common/conventional usage 95%) that a parameter will fall between a pair of values around the mean .  would like to mean water overalls. You can obtain this at Seaborn.
# - KDE: Kernel Density Estimation (KDE) is a non-parametric way to estimate the probability density function of a random variable.
# - Seaborn also adds these additional features into graphs by means of parameters easily. Moreover while using Seaborn for visualization you can easily reach the statistical summaries of mean, sd, variance etc. This gives us an analytical capacity to analyze the data and more flexiabilty than the other libraries do.
# - At Seaborn you can also get the std at the bars.
# - At your studies the order may be using 1) Seaborn, 2) Pandas and 3) matplotlip, respectively. Nevertheless, those all are necessary to combine the options of visualization for getting a better Data Analyst/Scientist.
# - If you know Statistics, making the statistical graphics is crucial to percieve underlying patterns of the data in EDA processing.
# - To sum up, it is necessary to know all of them.

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Seaborn Cheat Sheet</p>
#
# <a id="12"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# <img src=https://i.ibb.co/CwyVDr7/Python-Seaborn-Cheat-Sheet1024-1.jpg width="1000" height="200">
#
# **🧐 [Top 12 Cheat Sheets for Data Science in Python](https://medium.com/@d.goglia/top-12-cheat-sheet-for-data-science-in-python-4bf685dc3f37)**
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <a id="13"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#E51A59; font-size:150%; text-align:center; border-radius:10px 10px;">The End of Session-03 (Seaborn Part-01)</p>
#
#
# <p style="text-align: center;"><img src="https://i.ibb.co/TtRtYNn/healthy-lunch.jpg" width="800" height="200" class="img-fluid" alt="Lunch Time"></p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/99DQ3TY/DS-Courses.png" class="img-fluid" alt="CLRSWY_"></p>
#
# <br>
# <hr>
# <p style="text-align: center;"><img src="https://i.ibb.co/Rpz9L36/clarusway-logo-black.png" width="450" height="200" class="img-fluid" alt="CLRSWY_LOGO"></p>
#
# <p style="background-color:#E51A59; font-family:newtimeroman; color:#FDFEFE; font-size:130%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <a href="https://clarusway.com/contact-us/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="Open in Clarusway LMS" width="110" height="200" title="This notebook is licensed by Clarusway IT training school. Please contact the authorized persons about the conditions under which you can use or share."></a>
